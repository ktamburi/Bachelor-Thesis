# %%
# %pip install geopy ortools folium pulp
# Out:
# Requirement already satisfied: geopy in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (2.4.1)
# Requirement already satisfied: ortools in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (9.12.4544)
# Requirement already satisfied: folium in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (0.19.7)
# Requirement already satisfied: pulp in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (3.2.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from geopy) (2.0)
# Requirement already satisfied: absl-py>=2.0.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from ortools) (2.3.0)
# Requirement already satisfied: numpy>=1.13.3 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from ortools) (2.1.3)
# Requirement already satisfied: pandas>=2.0.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from ortools) (2.2.3)
# Requirement already satisfied: protobuf<5.30,>=5.29.3 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from ortools) (5.29.5)
# Requirement already satisfied: immutabledict>=3.0.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from ortools) (4.2.1)
# Requirement already satisfied: branca>=0.6.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from pandas>=2.0.0->ortools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from pandas>=2.0.0->ortools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from pandas>=2.0.0->ortools) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests->folium) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import time
from datetime import timedelta
from geopy.geocoders import Nominatim
from geopy.distance import great_circle
from ortools.constraint_solver import pywrapcp, routing_enums_pb2
import folium
import os
from pulp import LpProblem, LpVariable, lpSum, LpMinimize, LpInteger, value, LpStatusOptimal, PULP_CBC_CMD

def safe_name(s):
    return str(s).replace(" ", "_").replace("-", "_").replace(".", "_").replace("/", "_").replace(",", "_")

folder_name = "Maps"
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    

stores = pd.read_csv("stores_updated.csv")

forecasts = pd.read_csv("demand_forecasting.csv")
forecasts['date'] = pd.to_datetime(forecasts['date'])

oil_prices = pd.read_csv("oil_updated.csv")
oil_prices['date'] = pd.to_datetime(oil_prices['date'])

geolocator = Nominatim(user_agent="store_locator")

def get_city_coords(city, state, country="Ecuador"):
    try:
        location = geolocator.geocode(f"{city}, {state}, {country}")
        if location:
            return (location.latitude, location.longitude)
        else:
            return (None, None)
    except Exception as e:
        print(f"Error geocoding {city}, {state}: {e}")
        return (None, None)

# Geocode unique city/state pairs

geolocator = Nominatim(user_agent="store_locator")

coords_dict = {}
for idx, row in  stores[["City", "State"]].drop_duplicates().iterrows():
    city, state = row["City"], row["State"]
    lat, lon = get_city_coords(city, state)
    if lat and lon:
        coords_dict[(city, state)] = (lat, lon)
    else:
        coords_dict[(city, state)] = (0, 0)  # fallback
    time.sleep(1)  # respect rate limits

# Since multiple stores in same city/state and don't have long/lat, 
# changing values a bit to distinguish different stores
def add_jitter(lat, lon, max_jitter=0.005):
    jitter_lat = np.random.uniform(-max_jitter, max_jitter)
    jitter_lon = np.random.uniform(-max_jitter, max_jitter)
    return lat + jitter_lat, lon + jitter_lon

stores["Latitude"] = None
stores["Longitude"] = None

for idx, row in stores.iterrows():
    base_lat, base_lon = coords_dict.get((row["City"], row["State"]), (0, 0))
    lat_j, lon_j = add_jitter(base_lat, base_lon)
    stores.at[idx, "Latitude"] = lat_j
    stores.at[idx, "Longitude"] = lon_j

# Warehouse location (HQ)
warehouse_location = get_city_coords(city='Amaguaña', state='Quito')
    

def assign_delivery_days(Is_perishable):
    if is_perishable:
        return list(pd.date_range("2017-08-16", "2017-08-31", freq="2D"))
    else:
        return list(pd.date_range("2017-08-16", "2017-08-31", freq="5D"))

delivery_plan = []
for (store_id, product), group in forecasts.groupby(["Store", "ProductFamily"]):
    is_perishable = group["IsPerishable"].iloc[0]
    delivery_dates = assign_delivery_days(is_perishable)
    for date in delivery_dates:
        period_end = date + timedelta(days=1 if is_perishable else 4)
        mask = (group["date"] >= date) & (group["date"] <= period_end)
        demand_sum = np.ceil(group.loc[mask, "Demand"].sum())
        if demand_sum > 0:
            delivery_plan.append({
                "Store": store_id,
                "ProductFamily": product,
                "DeliveryDate": date,
                "Demand": demand_sum
            })
delivery_schedule_df = pd.DataFrame(delivery_plan)

# Merge stores info to delivery schedule for location
delivery_schedule_df = delivery_schedule_df.merge(stores, on="Store")

# %%
# ---- MILP Product Distribution & Stock Optimization ----

fee_per_unit = 0.0005
vehicle_capacity = 30000  

grouped = delivery_schedule_df.groupby(['DeliveryDate', 'ProductFamily'])
milp_results = []

for (delivery_date, product_family), group in grouped:
    print(f"\nMILP for {product_family} on {delivery_date.date()}")

    stores_group = group.reset_index(drop=True)
    store_ids = stores_group["Store"].tolist()
    demands = stores_group["Demand"].tolist()
    locations = list(zip(stores_group["Latitude"], stores_group["Longitude"]))

    dist_warehouse_to_stores = [great_circle(warehouse_location, loc).kilometers for loc in locations]

    prob = LpProblem(f"ProductDistribution_{safe_name(product_family)}_{safe_name(delivery_date.date())}", LpMinimize)

    qty_vars = {store_id: LpVariable(f"Qty_{store_id}", lowBound=0, cat=LpInteger) for store_id in store_ids}

    prob += lpSum([qty_vars[store_id] * dist * fee_per_unit for store_id, dist in zip(store_ids, dist_warehouse_to_stores)])

    for store_id, demand in zip(store_ids, demands):
        prob += qty_vars[store_id] >= demand, f"Demand_{store_id}"

    total_demand = sum(demands)
    vehicles_needed = int(np.ceil(total_demand / vehicle_capacity))
    prob += lpSum([qty_vars[store_id] for store_id in store_ids]) <= vehicles_needed * vehicle_capacity, "VehicleCapacity"

    solver = PULP_CBC_CMD(msg=False)
    prob.solve(solver)

    if prob.status != LpStatusOptimal:
        print("No optimal solution found!")
        continue

    shipment_quantities = {store_id: int(qty_vars[store_id].varValue) for store_id in store_ids}

    print(f"Vehicles needed (MILP): {vehicles_needed}")
    print("Shipments:")
    for sid, qty in shipment_quantities.items():
        print(f" Store {sid}: {qty} units")

    milp_results.append({
        "DeliveryDate": delivery_date,
        "ProductFamily": product_family,
        "Stores": stores_group,
        "ShipmentQuantities": shipment_quantities,
        "VehiclesNeeded": vehicles_needed
    })

shipment_aggregated = {}

for res in milp_results:
    delivery_date = res["DeliveryDate"]
    shipment_quantities = res["ShipmentQuantities"]

    for store_id, qty in shipment_quantities.items():
        key = (delivery_date, store_id)
        shipment_aggregated[key] = shipment_aggregated.get(key, 0) + qty

violations = []

for (delivery_date, store_id), total_qty in shipment_aggregated.items():
    store_capacity = stores.loc[stores["Store"] == store_id, "StoreCapacity"].values
    if len(store_capacity) == 0:
        print(f"Warning: Store {store_id} capacity not found!")
        continue
    capacity = store_capacity[0]

    if total_qty > capacity:
        violations.append({
            "DeliveryDate": delivery_date,
            "Store": store_id,
            "TotalShipment": total_qty,
            "Capacity": capacity,
            "Excess": total_qty - capacity
        })

if violations:
    print("\n*** Store capacity violations detected! Removing those stores for the affected delivery dates ***")
    for v in violations:
        print(f"Date: {v['DeliveryDate'].date()}, Store: {v['Store']}, Shipment: {v['TotalShipment']}, Capacity: {v['Capacity']}, Excess: {v['Excess']}")

    filtered_results = []
    for res in milp_results:
        delivery_date = res["DeliveryDate"]
        product_family = res["ProductFamily"]
        stores_group = res["Stores"]
        shipment_quantities = res["ShipmentQuantities"]
        vehicles_needed = res["VehiclesNeeded"]

        violating_stores = {v['Store'] for v in violations if v['DeliveryDate'] == delivery_date}

        mask = ~stores_group["Store"].isin(violating_stores)
        filtered_stores = stores_group[mask].reset_index(drop=True)

        filtered_shipment_quantities = {sid: qty for sid, qty in shipment_quantities.items() if sid not in violating_stores}

        total_qty = sum(filtered_shipment_quantities.values())
        vehicles_needed = int(np.ceil(total_qty / vehicle_capacity)) if total_qty > 0 else 0

        if len(filtered_stores) > 0 and vehicles_needed > 0:
            filtered_results.append({
                "DeliveryDate": delivery_date,
                "ProductFamily": product_family,
                "Stores": filtered_stores,
                "ShipmentQuantities": filtered_shipment_quantities,
                "VehiclesNeeded": vehicles_needed
            })
        else:
            print(f"All shipments removed for {product_family} on {delivery_date.date()} due to capacity violation")

    milp_results = filtered_results
else:
    print("\nNo store capacity violations detected.")
# Out:
# MILP for AUTOMOTIVE on 2017-08-16
# Vehicles needed (MILP): 4
# Shipments:
#  Store 1: 53 units
#  Store 2: 50 units
#  Store 3: 56 units
#  Store 4: 11140 units
#  Store 5: 43 units
#  Store 6: 1696 units
#  Store 7: 52 units
#  Store 8: 3090 units
#  Store 9: 3232 units
#  Store 10: 811 units
#  Store 11: 712 units
#  Store 12: 686 units
#  Store 13: 11875 units
#  Store 14: 61 units
#  Store 15: 46 units
#  Store 16: 68 units
#  Store 17: 83 units
#  Store 18: 45 units
#  Store 19: 939 units
#  Store 20: 57 units
#  Store 21: 75 units
#  Store 22: 53 units
#  Store 23: 562 units
#  Store 24: 51 units
#  Store 25: 1820 units
#  Store 26: 891 units
#  Store 27: 49 units
#  Store 28: 56 units
#  Store 29: 1649 units
#  Store 30: 315 units
#  Store 31: 13547 units
#  Store 32: 50 units
#  Store 33: 76 units
#  Store 34: 43 units
#  Store 35: 41 units
#  Store 36: 50 units
#  Store 37: 15156 units
#  Store 38: 43 units
#  Store 39: 3320 units
#  Store 40: 56 units
#  Store 41: 4429 units
#  Store 42: 4169 units
#  Store 43: 1332 units
#  Store 44: 926 units
#  Store 45: 629 units
#  Store 46: 20347 units
#  Store 47: 133 units
#  Store 48: 47 units
#  Store 49: 70 units
#  Store 50: 104 units
#  Store 51: 46 units
#  Store 52: 1340 units
#  Store 53: 72 units
#  Store 54: 74 units
#
# MILP for BABY CARE on 2017-08-16
# Vehicles needed (MILP): 8
# Shipments:
#  Store 1: 56 units
#  Store 2: 562 units
#  Store 3: 55 units
#  Store 4: 3373 units
#  Store 5: 1374 units
#  Store 6: 53 units
#  Store 7: 53 units
#  Store 8: 2665 units
#  Store 9: 634 units
#  Store 10: 13141 units
#  Store 11: 50 units
#  Store 12: 101 units
#  Store 13: 75 units
#  Store 14: 58 units
#  Store 15: 88 units
#  Store 16: 44862 units
#  Store 17: 56 units
#  Store 18: 6286 units
#  Store 19: 270 units
#  Store 20: 8869 units
#  Store 21: 9589 units
#  Store 22: 2138 units
#  Store 23: 2840 units
#  Store 24: 1823 units
#  Store 25: 39953 units
#  Store 26: 557 units
#  Store 27: 67 units
#  Store 28: 364 units
#  Store 29: 473 units
#  Store 30: 64 units
#  Store 31: 3047 units
#  Store 32: 270 units
#  Store 33: 440 units
#  Store 34: 184 units
#  Store 35: 1330 units
#  Store 36: 136 units
#  Store 37: 4282 units
#  Store 38: 3184 units
#  Store 39: 95 units
#  Store 40: 104 units
#  Store 41: 6309 units
#  Store 42: 1374 units
#  Store 43: 42183 units
#  Store 44: 71 units
#  Store 45: 603 units
#  Store 46: 42 units
#  Store 47: 39 units
#  Store 48: 44 units
#  Store 49: 13111 units
#  Store 50: 39 units
#  Store 51: 1920 units
#  Store 52: 45 units
#  Store 53: 4494 units
#  Store 54: 4044 units
#
# MILP for BEAUTY on 2017-08-16
# Vehicles needed (MILP): 3
# Shipments:
#  Store 1: 1191 units
#  Store 2: 749 units
#  Store 3: 538 units
#  Store 4: 17582 units
#  Store 5: 71 units
#  Store 6: 44 units
#  Store 7: 59 units
#  Store 8: 58 units
#  Store 9: 43 units
#  Store 10: 1275 units
#  Store 11: 62 units
#  Store 12: 72 units
#  Store 13: 46 units
#  Store 14: 564 units
#  Store 15: 49 units
#  Store 16: 2374 units
#  Store 17: 1360 units
#  Store 18: 48 units
#  Store 19: 51 units
#  Store 20: 2135 units
#  Store 21: 250 units
#  Store 22: 13135 units
#  Store 23: 46 units
#  Store 24: 81 units
#  Store 25: 39 units
#  Store 26: 36 units
#  Store 27: 40 units
#  Store 28: 8946 units
#  Store 29: 36 units
#  Store 30: 1802 units
#  Store 31: 58 units
#  Store 32: 4646 units
#  Store 33: 2945 units
#  Store 34: 1307 units
#  Store 35: 486 units
#  Store 36: 547 units
#  Store 37: 14603 units
#  Store 38: 228 units
#  Store 39: 41 units
#  Store 40: 76 units
#  Store 41: 71 units
#  Store 42: 40 units
#  Store 43: 1188 units
#  Store 44: 50 units
#  Store 45: 53 units
#  Store 46: 50 units
#  Store 47: 381 units
#  Store 48: 46 units
#  Store 49: 1412 units
#  Store 50: 1328 units
#  Store 51: 43 units
#  Store 52: 45 units
#  Store 53: 1340 units
#  Store 54: 300 units
#
# MILP for BEVERAGES on 2017-08-16
# Vehicles needed (MILP): 6
# Shipments:
#  Store 1: 7950 units
#  Store 2: 44 units
#  Store 3: 53 units
#  Store 4: 45 units
#  Store 5: 41 units
#  Store 6: 48 units
#  Store 7: 18737 units
#  Store 8: 42 units
#  Store 9: 3041 units
#  Store 10: 52 units
#  Store 11: 6505 units
#  Store 12: 5362 units
#  Store 13: 1901 units
#  Store 14: 1005 units
#  Store 15: 864 units
#  Store 16: 24915 units
#  Store 17: 101 units
#  Store 18: 46 units
#  Store 19: 80 units
#  Store 20: 345 units
#  Store 21: 46 units
#  Store 22: 1770 units
#  Store 23: 73 units
#  Store 24: 76 units
#  Store 25: 85 units
#  Store 26: 601 units
#  Store 27: 52 units
#  Store 28: 2804 units
#  Store 29: 1871 units
#  Store 30: 54 units
#  Store 31: 61 units
#  Store 32: 3161 units
#  Store 33: 596 units
#  Store 34: 14848 units
#  Store 35: 49 units
#  Store 36: 134 units
#  Store 37: 43 units
#  Store 38: 40 units
#  Store 39: 47 units
#  Store 40: 21111 units
#  Store 41: 41 units
#  Store 42: 3293 units
#  Store 43: 59 units
#  Store 44: 5150 units
#  Store 45: 6182 units
#  Store 46: 1180 units
#  Store 47: 1479 units
#  Store 48: 1271 units
#  Store 49: 19799 units
#  Store 50: 102 units
#  Store 51: 46 units
#  Store 52: 91 units
#  Store 53: 149 units
#  Store 54: 45 units
#
# MILP for BOOKS on 2017-08-16
# Vehicles needed (MILP): 6
# Shipments:
#  Store 1: 1321 units
#  Store 2: 59 units
#  Store 3: 218 units
#  Store 4: 59 units
#  Store 5: 1036 units
#  Store 6: 58 units
#  Store 7: 2890 units
#  Store 8: 1376 units
#  Store 9: 51 units
#  Store 10: 61 units
#  Store 11: 3440 units
#  Store 12: 734 units
#  Store 13: 26878 units
#  Store 14: 49 units
#  Store 15: 150 units
#  Store 16: 52 units
#  Store 17: 49 units
#  Store 18: 69 units
#  Store 19: 23626 units
#  Store 20: 50 units
#  Store 21: 4160 units
#  Store 22: 81 units
#  Store 23: 6110 units
#  Store 24: 6776 units
#  Store 25: 1600 units
#  Store 26: 1724 units
#  Store 27: 957 units
#  Store 28: 24369 units
#  Store 29: 181 units
#  Store 30: 58 units
#  Store 31: 165 units
#  Store 32: 362 units
#  Store 33: 53 units
#  Store 34: 1841 units
#  Store 35: 104 units
#  Store 36: 175 units
#  Store 37: 99 units
#  Store 38: 900 units
#  Store 39: 83 units
#  Store 40: 2597 units
#  Store 41: 1896 units
#  Store 42: 83 units
#  Store 43: 85 units
#  Store 44: 3622 units
#  Store 45: 877 units
#  Store 46: 25753 units
#  Store 47: 60 units
#  Store 48: 188 units
#  Store 49: 55 units
#  Store 50: 45 units
#  Store 51: 57 units
#  Store 52: 19111 units
#  Store 53: 46 units
#  Store 54: 2782 units
#
# MILP for BREAD/BAKERY on 2017-08-16
# Vehicles needed (MILP): 2
# Shipments:
#  Store 1: 25 units
#  Store 2: 2890 units
#  Store 3: 1420 units
#  Store 4: 1101 units
#  Store 5: 415 units
#  Store 6: 214 units
#  Store 7: 10895 units
#  Store 8: 25 units
#  Store 9: 20 units
#  Store 10: 75 units
#  Store 11: 83 units
#  Store 12: 19 units
#  Store 13: 796 units
#  Store 14: 23 units
#  Store 15: 23 units
#  Store 16: 28 units
#  Store 17: 153 units
#  Store 18: 20 units
#  Store 19: 882 units
#  Store 20: 918 units
#  Store 21: 22 units
#  Store 22: 22 units
#  Store 23: 818 units
#  Store 24: 230 units
#  Store 25: 2417 units
#  Store 26: 239 units
#  Store 27: 28 units
#  Store 28: 14 units
#  Store 29: 14 units
#  Store 30: 14 units
#  Store 31: 2654 units
#  Store 32: 14 units
#  Store 33: 223 units
#  Store 34: 15 units
#  Store 35: 1835 units
#  Store 36: 596 units
#  Store 37: 486 units
#  Store 38: 89 units
#  Store 39: 60 units
#  Store 40: 4683 units
#  Store 41: 16 units
#  Store 42: 15 units
#  Store 43: 18 units
#  Store 44: 18 units
#  Store 45: 15 units
#  Store 46: 349 units
#  Store 47: 15 units
#  Store 48: 16 units
#  Store 49: 15 units
#  Store 50: 24 units
#  Store 51: 15 units
#  Store 52: 385 units
#  Store 53: 372 units
#  Store 54: 15 units
#
# MILP for CELEBRATION on 2017-08-16
# Vehicles needed (MILP): 5
# Shipments:
#  Store 1: 38 units
#  Store 2: 871 units
#  Store 3: 85 units
#  Store 4: 1456 units
#  Store 5: 50 units
#  Store 6: 37 units
#  Store 7: 57 units
#  Store 8: 50 units
#  Store 9: 60 units
#  Store 10: 23715 units
#  Store 11: 51 units
#  Store 12: 3637 units
#  Store 13: 68 units
#  Store 14: 8436 units
#  Store 15: 3399 units
#  Store 16: 2911 units
#  Store 17: 1387 units
#  Store 18: 491 units
#  Store 19: 33701 units
#  Store 20: 111 units
#  Store 21: 53 units
#  Store 22: 93 units
#  Store 23: 90 units
#  Store 24: 52 units
#  Store 25: 2662 units
#  Store 26: 65 units
#  Store 27: 61 units
#  Store 28: 64 units
#  Store 29: 213 units
#  Store 30: 55 units
#  Store 31: 3564 units
#  Store 32: 2116 units
#  Store 33: 55 units
#  Store 34: 73 units
#  Store 35: 2323 units
#  Store 36: 621 units
#  Store 37: 6952 units
#  Store 38: 272 units
#  Store 39: 68 units
#  Store 40: 43 units
#  Store 41: 40 units
#  Store 42: 41 units
#  Store 43: 8317 units
#  Store 44: 41 units
#  Store 45: 1070 units
#  Store 46: 51 units
#  Store 47: 5437 units
#  Store 48: 2156 units
#  Store 49: 1203 units
#  Store 50: 383 units
#  Store 51: 209 units
#  Store 52: 14578 units
#  Store 53: 50 units
#  Store 54: 42 units
#
# MILP for CLEANING on 2017-08-16
# Vehicles needed (MILP): 2
# Shipments:
#  Store 1: 54 units
#  Store 2: 66 units
#  Store 3: 42 units
#  Store 4: 1000 units
#  Store 5: 47 units
#  Store 6: 44 units
#  Store 7: 66 units
#  Store 8: 192 units
#  Store 9: 43 units
#  Store 10: 924 units
#  Store 11: 1066 units
#  Store 12: 43 units
#  Store 13: 47 units
#  Store 14: 927 units
#  Store 15: 90 units
#  Store 16: 2038 units
#  Store 17: 63 units
#  Store 18: 45 units
#  Store 19: 36 units
#  Store 20: 34 units
#  Store 21: 37 units
#  Store 22: 8214 units
#  Store 23: 34 units
#  Store 24: 695 units
#  Store 25: 39 units
#  Store 26: 4857 units
#  Store 27: 1404 units
#  Store 28: 992 units
#  Store 29: 199 units
#  Store 30: 107 units
#  Store 31: 13233 units
#  Store 32: 50 units
#  Store 33: 35 units
#  Store 34: 48 units
#  Store 35: 44 units
#  Store 36: 35 units
#  Store 37: 777 units
#  Store 38: 36 units
#  Store 39: 37 units
#  Store 40: 36 units
#  Store 41: 171 units
#  Store 42: 35 units
#  Store 43: 955 units
#  Store 44: 1136 units
#  Store 45: 35 units
#  Store 46: 38 units
#  Store 47: 545 units
#  Store 48: 67 units
#  Store 49: 1220 units
#  Store 50: 65 units
#  Store 51: 36 units
#  Store 52: 41 units
#  Store 53: 39 units
#  Store 54: 43 units
#
# MILP for DAIRY on 2017-08-16
# Vehicles needed (MILP): 1
# Shipments:
#  Store 1: 3038 units
#  Store 2: 16 units
#  Store 3: 336 units
#  Store 4: 19 units
#  Store 5: 2508 units
#  Store 6: 802 units
#  Store 7: 531 units
#  Store 8: 57 units
#  Store 9: 72 units
#  Store 10: 5370 units
#  Store 11: 19 units
#  Store 12: 16 units
#  Store 13: 19 units
#  Store 14: 26 units
#  Store 15: 16 units
#  Store 16: 413 units
#  Store 17: 16 units
#  Store 18: 17 units
#  Store 19: 17 units
#  Store 20: 25 units
#  Store 21: 17 units
#  Store 22: 525 units
#  Store 23: 529 units
#  Store 24: 16 units
#  Store 25: 17 units
#  Store 26: 182 units
#  Store 27: 199 units
#  Store 28: 880 units
#  Store 29: 24 units
#  Store 30: 18 units
#  Store 31: 18 units
#  Store 32: 17 units
#  Store 33: 19 units
#  Store 34: 3316 units
#  Store 35: 17 units
#  Store 36: 322 units
#  Store 37: 18 units
#  Store 38: 1872 units
#  Store 39: 732 units
#  Store 40: 567 units
#  Store 41: 217 units
#  Store 42: 156 units
#  Store 43: 5482 units
#  Store 44: 20 units
#  Store 45: 18 units
#  Store 46: 23 units
#  Store 47: 26 units
#  Store 48: 17 units
#  Store 49: 463 units
#  Store 50: 20 units
#  Store 51: 19 units
#  Store 52: 19 units
#  Store 53: 33 units
#  Store 54: 18 units
#
# MILP for DELI on 2017-08-16
# Vehicles needed (MILP): 1
# Shipments:
#  Store 1: 275 units
#  Store 2: 415 units
#  Store 3: 18 units
#  Store 4: 19 units
#  Store 5: 233 units
#  Store 6: 66 units
#  Store 7: 1336 units
#  Store 8: 31 units
#  Store 9: 19 units
#  Store 10: 14 units
#  Store 11: 14 units
#  Store 12: 15 units
#  Store 13: 2411 units
#  Store 14: 14 units
#  Store 15: 299 units
#  Store 16: 15 units
#  Store 17: 1785 units
#  Store 18: 471 units
#  Store 19: 349 units
#  Store 20: 346 units
#  Store 21: 59 units
#  Store 22: 3773 units
#  Store 23: 16 units
#  Store 24: 14 units
#  Store 25: 21 units
#  Store 26: 23 units
#  Store 27: 14 units
#  Store 28: 330 units
#  Store 29: 14 units
#  Store 30: 16 units
#  Store 31: 15 units
#  Store 32: 42 units
#  Store 33: 14 units
#  Store 34: 113 units
#  Store 35: 276 units
#  Store 36: 14 units
#  Store 37: 15 units
#  Store 38: 128 units
#  Store 39: 35 units
#  Store 40: 1195 units
#  Store 41: 16 units
#  Store 42: 15 units
#  Store 43: 19 units
#  Store 44: 18 units
#  Store 45: 20 units
#  Store 46: 5734 units
#  Store 47: 18 units
#  Store 48: 600 units
#  Store 49: 19 units
#  Store 50: 2116 units
#  Store 51: 1347 units
#  Store 52: 1013 units
#  Store 53: 398 units
#  Store 54: 222 units
#
# MILP for EGGS on 2017-08-16
# Vehicles needed (MILP): 2
# Shipments:
#  Store 1: 8038 units
#  Store 2: 24 units
#  Store 3: 18 units
#  Store 4: 27 units
#  Store 5: 31 units
#  Store 6: 18 units
#  Store 7: 545 units
#  Store 8: 18 units
#  Store 9: 19 units
#  Store 10: 27 units
#  Store 11: 86 units
#  Store 12: 19 units
#  Store 13: 488 units
#  Store 14: 540 units
#  Store 15: 18 units
#  Store 16: 20 units
#  Store 17: 695 units
#  Store 18: 124 units
#  Store 19: 2255 units
#  Store 20: 40 units
#  Store 21: 22 units
#  Store 22: 18 units
#  Store 23: 17 units
#  Store 24: 21 units
#  Store 25: 4047 units
#  Store 26: 18 units
#  Store 27: 1116 units
#  Store 28: 21 units
#  Store 29: 1161 units
#  Store 30: 1130 units
#  Store 31: 453 units
#  Store 32: 394 units
#  Store 33: 145 units
#  Store 34: 5164 units
#  Store 35: 24 units
#  Store 36: 18 units
#  Store 37: 32 units
#  Store 38: 28 units
#  Store 39: 18 units
#  Store 40: 394 units
#  Store 41: 21 units
#  Store 42: 21 units
#  Store 43: 23 units
#  Store 44: 138 units
#  Store 45: 18 units
#  Store 46: 244 units
#  Store 47: 353 units
#  Store 48: 19 units
#  Store 49: 20 units
#  Store 50: 365 units
#  Store 51: 114 units
#  Store 52: 2515 units
#  Store 53: 146 units
#  Store 54: 24 units
#
# MILP for FROZEN FOODS on 2017-08-16
# Vehicles needed (MILP): 5
# Shipments:
#  Store 1: 41 units
#  Store 2: 38 units
#  Store 3: 41 units
#  Store 4: 13751 units
#  Store 5: 38 units
#  Store 6: 1049 units
#  Store 7: 42 units
#  Store 8: 5292 units
#  Store 9: 1830 units
#  Store 10: 1504 units
#  Store 11: 341 units
#  Store 12: 138 units
#  Store 13: 17920 units
#  Store 14: 96 units
#  Store 15: 39 units
#  Store 16: 47 units
#  Store 17: 55 units
#  Store 18: 39 units
#  Store 19: 1090 units
#  Store 20: 44 units
#  Store 21: 40 units
#  Store 22: 41 units
#  Store 23: 213 units
#  Store 24: 40 units
#  Store 25: 841 units
#  Store 26: 1146 units
#  Store 27: 39 units
#  Store 28: 42 units
#  Store 29: 746 units
#  Store 30: 64 units
#  Store 31: 2875 units
#  Store 32: 57 units
#  Store 33: 41 units
#  Store 34: 48 units
#  Store 35: 43 units
#  Store 36: 50 units
#  Store 37: 20007 units
#  Store 38: 43 units
#  Store 39: 3216 units
#  Store 40: 49 units
#  Store 41: 9927 units
#  Store 42: 3993 units
#  Store 43: 3791 units
#  Store 44: 647 units
#  Store 45: 468 units
#  Store 46: 29807 units
#  Store 47: 57 units
#  Store 48: 44 units
#  Store 49: 64 units
#  Store 50: 63 units
#  Store 51: 43 units
#  Store 52: 1949 units
#  Store 53: 45 units
#  Store 54: 52 units
#
# MILP for GROCERY I on 2017-08-16
# Vehicles needed (MILP): 4
# Shipments:
#  Store 1: 51 units
#  Store 2: 295 units
#  Store 3: 44 units
#  Store 4: 2244 units
#  Store 5: 2285 units
#  Store 6: 46 units
#  Store 7: 48 units
#  Store 8: 1991 units
#  Store 9: 399 units
#  Store 10: 6208 units
#  Store 11: 404 units
#  Store 12: 57 units
#  Store 13: 44 units
#  Store 14: 38 units
#  Store 15: 42 units
#  Store 16: 16556 units
#  Store 17: 38 units
#  Store 18: 2694 units
#  Store 19: 42 units
#  Store 20: 7657 units
#  Store 21: 3347 units
#  Store 22: 1870 units
#  Store 23: 1267 units
#  Store 24: 493 units
#  Store 25: 21486 units
#  Store 26: 51 units
#  Store 27: 39 units
#  Store 28: 96 units
#  Store 29: 97 units
#  Store 30: 39 units
#  Store 31: 1879 units
#  Store 32: 41 units
#  Store 33: 43 units
#  Store 34: 45 units
#  Store 35: 459 units
#  Store 36: 40 units
#  Store 37: 705 units
#  Store 38: 1679 units
#  Store 39: 40 units
#  Store 40: 42 units
#  Store 41: 1060 units
#  Store 42: 955 units
#  Store 43: 6626 units
#  Store 44: 40 units
#  Store 45: 43 units
#  Store 46: 35 units
#  Store 47: 33 units
#  Store 48: 36 units
#  Store 49: 8409 units
#  Store 50: 35 units
#  Store 51: 840 units
#  Store 52: 44 units
#  Store 53: 4909 units
#  Store 54: 1711 units
#
# MILP for GROCERY II on 2017-08-16
# Vehicles needed (MILP): 2
# Shipments:
#  Store 1: 877 units
#  Store 2: 232 units
#  Store 3: 258 units
#  Store 4: 12061 units
#  Store 5: 47 units
#  Store 6: 35 units
#  Store 7: 83 units
#  Store 8: 79 units
#  Store 9: 35 units
#  Store 10: 1029 units
#  Store 11: 35 units
#  Store 12: 39 units
#  Store 13: 38 units
#  Store 14: 510 units
#  Store 15: 36 units
#  Store 16: 678 units
#  Store 17: 929 units
#  Store 18: 36 units
#  Store 19: 40 units
#  Store 20: 1005 units
#  Store 21: 86 units
#  Store 22: 2936 units
#  Store 23: 80 units
#  Store 24: 37 units
#  Store 25: 37 units
#  Store 26: 36 units
#  Store 27: 39 units
#  Store 28: 7685 units
#  Store 29: 37 units
#  Store 30: 1358 units
#  Store 31: 46 units
#  Store 32: 3089 units
#  Store 33: 2811 units
#  Store 34: 776 units
#  Store 35: 250 units
#  Store 36: 335 units
#  Store 37: 10608 units
#  Store 38: 74 units
#  Store 39: 37 units
#  Store 40: 46 units
#  Store 41: 73 units
#  Store 42: 37 units
#  Store 43: 717 units
#  Store 44: 47 units
#  Store 45: 42 units
#  Store 46: 44 units
#  Store 47: 284 units
#  Store 48: 40 units
#  Store 49: 3442 units
#  Store 50: 854 units
#  Store 51: 39 units
#  Store 52: 40 units
#  Store 53: 1682 units
#  Store 54: 94 units
#
# MILP for HARDWARE on 2017-08-16
# Vehicles needed (MILP): 5
# Shipments:
#  Store 1: 6103 units
#  Store 2: 40 units
#  Store 3: 44 units
#  Store 4: 47 units
#  Store 5: 45 units
#  Store 6: 53 units
#  Store 7: 19378 units
#  Store 8: 46 units
#  Store 9: 3834 units
#  Store 10: 65 units
#  Store 11: 5585 units
#  Store 12: 6339 units
#  Store 13: 1510 units
#  Store 14: 1340 units
#  Store 15: 1034 units
#  Store 16: 21261 units
#  Store 17: 104 units
#  Store 18: 47 units
#  Store 19: 73 units
#  Store 20: 149 units
#  Store 21: 46 units
#  Store 22: 1406 units
#  Store 23: 59 units
#  Store 24: 164 units
#  Store 25: 59 units
#  Store 26: 545 units
#  Store 27: 61 units
#  Store 28: 2422 units
#  Store 29: 1418 units
#  Store 30: 66 units
#  Store 31: 56 units
#  Store 32: 3192 units
#  Store 33: 692 units
#  Store 34: 19443 units
#  Store 35: 51 units
#  Store 36: 81 units
#  Store 37: 34 units
#  Store 38: 33 units
#  Store 39: 35 units
#  Store 40: 10494 units
#  Store 41: 33 units
#  Store 42: 2275 units
#  Store 43: 37 units
#  Store 44: 2697 units
#  Store 45: 3578 units
#  Store 46: 900 units
#  Store 47: 757 units
#  Store 48: 746 units
#  Store 49: 10169 units
#  Store 50: 60 units
#  Store 51: 34 units
#  Store 52: 47 units
#  Store 53: 52 units
#  Store 54: 33 units
#
# MILP for HOME AND KITCHEN I on 2017-08-16
# Vehicles needed (MILP): 3
# Shipments:
#  Store 1: 648 units
#  Store 2: 33 units
#  Store 3: 76 units
#  Store 4: 35 units
#  Store 5: 1461 units
#  Store 6: 38 units
#  Store 7: 1413 units
#  Store 8: 677 units
#  Store 9: 35 units
#  Store 10: 37 units
#  Store 11: 1152 units
#  Store 12: 95 units
#  Store 13: 8931 units
#  Store 14: 34 units
#  Store 15: 37 units
#  Store 16: 44 units
#  Store 17: 37 units
#  Store 18: 41 units
#  Store 19: 5072 units
#  Store 20: 48 units
#  Store 21: 1184 units
#  Store 22: 60 units
#  Store 23: 2078 units
#  Store 24: 1295 units
#  Store 25: 446 units
#  Store 26: 169 units
#  Store 27: 88 units
#  Store 28: 7651 units
#  Store 29: 70 units
#  Store 30: 55 units
#  Store 31: 66 units
#  Store 32: 66 units
#  Store 33: 54 units
#  Store 34: 393 units
#  Store 35: 53 units
#  Store 36: 68 units
#  Store 37: 57 units
#  Store 38: 86 units
#  Store 39: 53 units
#  Store 40: 1542 units
#  Store 41: 745 units
#  Store 42: 57 units
#  Store 43: 56 units
#  Store 44: 871 units
#  Store 45: 78 units
#  Store 46: 2742 units
#  Store 47: 60 units
#  Store 48: 58 units
#  Store 49: 49 units
#  Store 50: 44 units
#  Store 51: 50 units
#  Store 52: 17561 units
#  Store 53: 45 units
#  Store 54: 3595 units
#
# MILP for HOME AND KITCHEN II on 2017-08-16
# Vehicles needed (MILP): 5
# Shipments:
#  Store 1: 61 units
#  Store 2: 4879 units
#  Store 3: 5592 units
#  Store 4: 1646 units
#  Store 5: 1319 units
#  Store 6: 837 units
#  Store 7: 20156 units
#  Store 8: 85 units
#  Store 9: 47 units
#  Store 10: 65 units
#  Store 11: 103 units
#  Store 12: 45 units
#  Store 13: 1307 units
#  Store 14: 51 units
#  Store 15: 182 units
#  Store 16: 54 units
#  Store 17: 1150 units
#  Store 18: 48 units
#  Store 19: 1608 units
#  Store 20: 1388 units
#  Store 21: 54 units
#  Store 22: 53 units
#  Store 23: 2240 units
#  Store 24: 505 units
#  Store 25: 14953 units
#  Store 26: 49 units
#  Store 27: 69 units
#  Store 28: 44 units
#  Store 29: 41 units
#  Store 30: 44 units
#  Store 31: 19346 units
#  Store 32: 41 units
#  Store 33: 3468 units
#  Store 34: 53 units
#  Store 35: 6461 units
#  Store 36: 4815 units
#  Store 37: 2053 units
#  Store 38: 1332 units
#  Store 39: 413 units
#  Store 40: 25365 units
#  Store 41: 56 units
#  Store 42: 42 units
#  Store 43: 92 units
#  Store 44: 68 units
#  Store 45: 42 units
#  Store 46: 1439 units
#  Store 47: 41 units
#  Store 48: 48 units
#  Store 49: 45 units
#  Store 50: 323 units
#  Store 51: 42 units
#  Store 52: 1201 units
#  Store 53: 1655 units
#  Store 54: 44 units
#
# MILP for HOME APPLIANCES on 2017-08-16
# Vehicles needed (MILP): 4
# Shipments:
#  Store 1: 44 units
#  Store 2: 1250 units
#  Store 3: 479 units
#  Store 4: 7320 units
#  Store 5: 45 units
#  Store 6: 45 units
#  Store 7: 43 units
#  Store 8: 40 units
#  Store 9: 43 units
#  Store 10: 18253 units
#  Store 11: 40 units
#  Store 12: 3604 units
#  Store 13: 49 units
#  Store 14: 5347 units
#  Store 15: 3831 units
#  Store 16: 1455 units
#  Store 17: 1205 units
#  Store 18: 468 units
#  Store 19: 20329 units
#  Store 20: 56 units
#  Store 21: 42 units
#  Store 22: 75 units
#  Store 23: 67 units
#  Store 24: 41 units
#  Store 25: 1390 units
#  Store 26: 41 units
#  Store 27: 49 units
#  Store 28: 45 units
#  Store 29: 625 units
#  Store 30: 42 units
#  Store 31: 707 units
#  Store 32: 1363 units
#  Store 33: 44 units
#  Store 34: 44 units
#  Store 35: 1135 units
#  Store 36: 348 units
#  Store 37: 6182 units
#  Store 38: 44 units
#  Store 39: 46 units
#  Store 40: 34 units
#  Store 41: 32 units
#  Store 42: 33 units
#  Store 43: 6789 units
#  Store 44: 33 units
#  Store 45: 846 units
#  Store 46: 40 units
#  Store 47: 4279 units
#  Store 48: 1366 units
#  Store 49: 705 units
#  Store 50: 845 units
#  Store 51: 198 units
#  Store 52: 10113 units
#  Store 53: 43 units
#  Store 54: 35 units
#
# MILP for HOME CARE on 2017-08-16
# Vehicles needed (MILP): 3
# Shipments:
#  Store 1: 66 units
#  Store 2: 55 units
#  Store 3: 35 units
#  Store 4: 1005 units
#  Store 5: 35 units
#  Store 6: 42 units
#  Store 7: 39 units
#  Store 8: 132 units
#  Store 9: 35 units
#  Store 10: 349 units
#  Store 11: 521 units
#  Store 12: 37 units
#  Store 13: 39 units
#  Store 14: 612 units
#  Store 15: 78 units
#  Store 16: 2779 units
#  Store 17: 42 units
#  Store 18: 41 units
#  Store 19: 48 units
#  Store 20: 42 units
#  Store 21: 44 units
#  Store 22: 19508 units
#  Store 23: 42 units
#  Store 24: 3072 units
#  Store 25: 50 units
#  Store 26: 6805 units
#  Store 27: 3533 units
#  Store 28: 1363 units
#  Store 29: 1630 units
#  Store 30: 521 units
#  Store 31: 24429 units
#  Store 32: 57 units
#  Store 33: 43 units
#  Store 34: 68 units
#  Store 35: 72 units
#  Store 36: 43 units
#  Store 37: 1550 units
#  Store 38: 44 units
#  Store 39: 51 units
#  Store 40: 51 units
#  Store 41: 75 units
#  Store 42: 44 units
#  Store 43: 2320 units
#  Store 44: 1416 units
#  Store 45: 46 units
#  Store 46: 48 units
#  Store 47: 734 units
#  Store 48: 381 units
#  Store 49: 6572 units
#  Store 50: 47 units
#  Store 51: 48 units
#  Store 52: 33 units
#  Store 53: 32 units
#  Store 54: 34 units
#
# MILP for LADIESWEAR on 2017-08-16
# Vehicles needed (MILP): 3
# Shipments:
#  Store 1: 5917 units
#  Store 2: 34 units
#  Store 3: 681 units
#  Store 4: 41 units
#  Store 5: 4537 units
#  Store 6: 990 units
#  Store 7: 516 units
#  Store 8: 1138 units
#  Store 9: 77 units
#  Store 10: 10114 units
#  Store 11: 40 units
#  Store 12: 37 units
#  Store 13: 60 units
#  Store 14: 46 units
#  Store 15: 36 units
#  Store 16: 428 units
#  Store 17: 36 units
#  Store 18: 45 units
#  Store 19: 39 units
#  Store 20: 94 units
#  Store 21: 36 units
#  Store 22: 350 units
#  Store 23: 351 units
#  Store 24: 37 units
#  Store 25: 38 units
#  Store 26: 230 units
#  Store 27: 62 units
#  Store 28: 1286 units
#  Store 29: 44 units
#  Store 30: 40 units
#  Store 31: 44 units
#  Store 32: 36 units
#  Store 33: 38 units
#  Store 34: 9776 units
#  Store 35: 36 units
#  Store 36: 1243 units
#  Store 37: 46 units
#  Store 38: 5183 units
#  Store 39: 2331 units
#  Store 40: 1117 units
#  Store 41: 1143 units
#  Store 42: 348 units
#  Store 43: 14413 units
#  Store 44: 40 units
#  Store 45: 37 units
#  Store 46: 97 units
#  Store 47: 68 units
#  Store 48: 36 units
#  Store 49: 1332 units
#  Store 50: 36 units
#  Store 51: 39 units
#  Store 52: 55 units
#  Store 53: 146 units
#  Store 54: 38 units
#
# MILP for LAWN AND GARDEN on 2017-08-16
# Vehicles needed (MILP): 3
# Shipments:
#  Store 1: 1426 units
#  Store 2: 1224 units
#  Store 3: 38 units
#  Store 4: 39 units
#  Store 5: 1286 units
#  Store 6: 90 units
#  Store 7: 6127 units
#  Store 8: 39 units
#  Store 9: 38 units
#  Store 10: 49 units
#  Store 11: 46 units
#  Store 12: 48 units
#  Store 13: 12711 units
#  Store 14: 46 units
#  Store 15: 3315 units
#  Store 16: 55 units
#  Store 17: 4484 units
#  Store 18: 3287 units
#  Store 19: 1300 units
#  Store 20: 697 units
#  Store 21: 380 units
#  Store 22: 21159 units
#  Store 23: 58 units
#  Store 24: 50 units
#  Store 25: 86 units
#  Store 26: 147 units
#  Store 27: 47 units
#  Store 28: 1195 units
#  Store 29: 48 units
#  Store 30: 59 units
#  Store 31: 51 units
#  Store 32: 116 units
#  Store 33: 49 units
#  Store 34: 1032 units
#  Store 35: 1380 units
#  Store 36: 50 units
#  Store 37: 53 units
#  Store 38: 784 units
#  Store 39: 98 units
#  Store 40: 3267 units
#  Store 41: 54 units
#  Store 42: 51 units
#  Store 43: 32 units
#  Store 44: 31 units
#  Store 45: 32 units
#  Store 46: 7023 units
#  Store 47: 31 units
#  Store 48: 540 units
#  Store 49: 33 units
#  Store 50: 2784 units
#  Store 51: 1042 units
#  Store 52: 551 units
#  Store 53: 908 units
#  Store 54: 213 units
#
# MILP for LINGERIE on 2017-08-16
# Vehicles needed (MILP): 3
# Shipments:
#  Store 1: 10090 units
#  Store 2: 38 units
#  Store 3: 32 units
#  Store 4: 41 units
#  Store 5: 41 units
#  Store 6: 32 units
#  Store 7: 521 units
#  Store 8: 32 units
#  Store 9: 36 units
#  Store 10: 33 units
#  Store 11: 214 units
#  Store 12: 32 units
#  Store 13: 1149 units
#  Store 14: 427 units
#  Store 15: 32 units
#  Store 16: 33 units
#  Store 17: 220 units
#  Store 18: 62 units
#  Store 19: 2188 units
#  Store 20: 36 units
#  Store 21: 33 units
#  Store 22: 42 units
#  Store 23: 39 units
#  Store 24: 41 units
#  Store 25: 19424 units
#  Store 26: 39 units
#  Store 27: 2843 units
#  Store 28: 49 units
#  Store 29: 4730 units
#  Store 30: 3172 units
#  Store 31: 1230 units
#  Store 32: 746 units
#  Store 33: 650 units
#  Store 34: 19537 units
#  Store 35: 47 units
#  Store 36: 40 units
#  Store 37: 91 units
#  Store 38: 57 units
#  Store 39: 40 units
#  Store 40: 1242 units
#  Store 41: 40 units
#  Store 42: 96 units
#  Store 43: 43 units
#  Store 44: 393 units
#  Store 45: 41 units
#  Store 46: 1415 units
#  Store 47: 1240 units
#  Store 48: 42 units
#  Store 49: 43 units
#  Store 50: 720 units
#  Store 51: 172 units
#  Store 52: 6484 units
#  Store 53: 43 units
#  Store 54: 42 units
#
# MILP for LIQUOR,WINE,BEER on 2017-08-16
# Vehicles needed (MILP): 4
# Shipments:
#  Store 1: 45 units
#  Store 2: 42 units
#  Store 3: 54 units
#  Store 4: 14384 units
#  Store 5: 42 units
#  Store 6: 2678 units
#  Store 7: 49 units
#  Store 8: 4592 units
#  Store 9: 4246 units
#  Store 10: 939 units
#  Store 11: 696 units
#  Store 12: 666 units
#  Store 13: 18438 units
#  Store 14: 243 units
#  Store 15: 44 units
#  Store 16: 84 units
#  Store 17: 95 units
#  Store 18: 43 units
#  Store 19: 1325 units
#  Store 20: 67 units
#  Store 21: 78 units
#  Store 22: 46 units
#  Store 23: 664 units
#  Store 24: 52 units
#  Store 25: 1323 units
#  Store 26: 1461 units
#  Store 27: 55 units
#  Store 28: 57 units
#  Store 29: 1396 units
#  Store 30: 400 units
#  Store 31: 13393 units
#  Store 32: 47 units
#  Store 33: 56 units
#  Store 34: 48 units
#  Store 35: 44 units
#  Store 36: 53 units
#  Store 37: 14246 units
#  Store 38: 44 units
#  Store 39: 2472 units
#  Store 40: 55 units
#  Store 41: 5764 units
#  Store 42: 4248 units
#  Store 43: 911 units
#  Store 44: 528 units
#  Store 45: 632 units
#  Store 46: 20334 units
#  Store 47: 82 units
#  Store 48: 45 units
#  Store 49: 135 units
#  Store 50: 363 units
#  Store 51: 44 units
#  Store 52: 1824 units
#  Store 53: 68 units
#  Store 54: 65 units
#
# MILP for MAGAZINES on 2017-08-16
# Vehicles needed (MILP): 5
# Shipments:
#  Store 1: 53 units
#  Store 2: 640 units
#  Store 3: 54 units
#  Store 4: 939 units
#  Store 5: 2289 units
#  Store 6: 50 units
#  Store 7: 54 units
#  Store 8: 719 units
#  Store 9: 487 units
#  Store 10: 11911 units
#  Store 11: 51 units
#  Store 12: 66 units
#  Store 13: 49 units
#  Store 14: 43 units
#  Store 15: 49 units
#  Store 16: 20204 units
#  Store 17: 43 units
#  Store 18: 3500 units
#  Store 19: 47 units
#  Store 20: 7902 units
#  Store 21: 3317 units
#  Store 22: 1172 units
#  Store 23: 1876 units
#  Store 24: 378 units
#  Store 25: 25804 units
#  Store 26: 99 units
#  Store 27: 45 units
#  Store 28: 66 units
#  Store 29: 66 units
#  Store 30: 43 units
#  Store 31: 1821 units
#  Store 32: 47 units
#  Store 33: 61 units
#  Store 34: 55 units
#  Store 35: 320 units
#  Store 36: 46 units
#  Store 37: 931 units
#  Store 38: 1657 units
#  Store 39: 48 units
#  Store 40: 51 units
#  Store 41: 1308 units
#  Store 42: 235 units
#  Store 43: 7192 units
#  Store 44: 80 units
#  Store 45: 57 units
#  Store 46: 43 units
#  Store 47: 41 units
#  Store 48: 46 units
#  Store 49: 24670 units
#  Store 50: 42 units
#  Store 51: 2283 units
#  Store 52: 50 units
#  Store 53: 8352 units
#  Store 54: 3302 units
#
# MILP for MEATS on 2017-08-16
# Vehicles needed (MILP): 2
# Shipments:
#  Store 1: 545 units
#  Store 2: 374 units
#  Store 3: 155 units
#  Store 4: 9354 units
#  Store 5: 21 units
#  Store 6: 17 units
#  Store 7: 30 units
#  Store 8: 30 units
#  Store 9: 17 units
#  Store 10: 852 units
#  Store 11: 17 units
#  Store 12: 18 units
#  Store 13: 20 units
#  Store 14: 69 units
#  Store 15: 17 units
#  Store 16: 284 units
#  Store 17: 607 units
#  Store 18: 18 units
#  Store 19: 20 units
#  Store 20: 380 units
#  Store 21: 112 units
#  Store 22: 2177 units
#  Store 23: 18 units
#  Store 24: 19 units
#  Store 25: 17 units
#  Store 26: 16 units
#  Store 27: 18 units
#  Store 28: 4198 units
#  Store 29: 16 units
#  Store 30: 907 units
#  Store 31: 18 units
#  Store 32: 2157 units
#  Store 33: 1260 units
#  Store 34: 438 units
#  Store 35: 267 units
#  Store 36: 289 units
#  Store 37: 6580 units
#  Store 38: 61 units
#  Store 39: 16 units
#  Store 40: 24 units
#  Store 41: 42 units
#  Store 42: 16 units
#  Store 43: 462 units
#  Store 44: 22 units
#  Store 45: 24 units
#  Store 46: 18 units
#  Store 47: 256 units
#  Store 48: 19 units
#  Store 49: 544 units
#  Store 50: 766 units
#  Store 51: 19 units
#  Store 52: 18 units
#  Store 53: 385 units
#  Store 54: 134 units
#
# MILP for PERSONAL CARE on 2017-08-16
# Vehicles needed (MILP): 5
# Shipments:
#  Store 1: 12681 units
#  Store 2: 41 units
#  Store 3: 45 units
#  Store 4: 45 units
#  Store 5: 42 units
#  Store 6: 49 units
#  Store 7: 13397 units
#  Store 8: 42 units
#  Store 9: 2569 units
#  Store 10: 49 units
#  Store 11: 4046 units
#  Store 12: 4466 units
#  Store 13: 1047 units
#  Store 14: 745 units
#  Store 15: 674 units
#  Store 16: 15450 units
#  Store 17: 95 units
#  Store 18: 43 units
#  Store 19: 84 units
#  Store 20: 82 units
#  Store 21: 42 units
#  Store 22: 1188 units
#  Store 23: 56 units
#  Store 24: 194 units
#  Store 25: 52 units
#  Store 26: 423 units
#  Store 27: 50 units
#  Store 28: 1314 units
#  Store 29: 1323 units
#  Store 30: 49 units
#  Store 31: 49 units
#  Store 32: 1265 units
#  Store 33: 243 units
#  Store 34: 13018 units
#  Store 35: 46 units
#  Store 36: 61 units
#  Store 37: 47 units
#  Store 38: 43 units
#  Store 39: 48 units
#  Store 40: 26919 units
#  Store 41: 43 units
#  Store 42: 3127 units
#  Store 43: 59 units
#  Store 44: 6218 units
#  Store 45: 3523 units
#  Store 46: 1569 units
#  Store 47: 1298 units
#  Store 48: 411 units
#  Store 49: 25983 units
#  Store 50: 54 units
#  Store 51: 44 units
#  Store 52: 60 units
#  Store 53: 72 units
#  Store 54: 43 units
#
# MILP for PET SUPPLIES on 2017-08-16
# Vehicles needed (MILP): 10
# Shipments:
#  Store 1: 1378 units
#  Store 2: 43 units
#  Store 3: 56 units
#  Store 4: 45 units
#  Store 5: 537 units
#  Store 6: 45 units
#  Store 7: 1239 units
#  Store 8: 1582 units
#  Store 9: 46 units
#  Store 10: 45 units
#  Store 11: 1388 units
#  Store 12: 743 units
#  Store 13: 6363 units
#  Store 14: 47 units
#  Store 15: 44 units
#  Store 16: 94 units
#  Store 17: 68 units
#  Store 18: 104 units
#  Store 19: 52954 units
#  Store 20: 69 units
#  Store 21: 7926 units
#  Store 22: 110 units
#  Store 23: 13011 units
#  Store 24: 12501 units
#  Store 25: 3268 units
#  Store 26: 3634 units
#  Store 27: 2414 units
#  Store 28: 50370 units
#  Store 29: 585 units
#  Store 30: 75 units
#  Store 31: 694 units
#  Store 32: 797 units
#  Store 33: 68 units
#  Store 34: 4034 units
#  Store 35: 588 units
#  Store 36: 195 units
#  Store 37: 633 units
#  Store 38: 1906 units
#  Store 39: 104 units
#  Store 40: 5056 units
#  Store 41: 3647 units
#  Store 42: 275 units
#  Store 43: 262 units
#  Store 44: 6307 units
#  Store 45: 1582 units
#  Store 46: 50818 units
#  Store 47: 1801 units
#  Store 48: 630 units
#  Store 49: 99 units
#  Store 50: 74 units
#  Store 51: 103 units
#  Store 52: 49508 units
#  Store 53: 74 units
#  Store 54: 6476 units
#
# MILP for PLAYERS AND ELECTRONICS on 2017-08-16
# Vehicles needed (MILP): 10
# Shipments:
#  Store 1: 151 units
#  Store 2: 13205 units
#  Store 3: 10789 units
#  Store 4: 3998 units
#  Store 5: 2099 units
#  Store 6: 1825 units
#  Store 7: 55341 units
#  Store 8: 840 units
#  Store 9: 76 units
#  Store 10: 536 units
#  Store 11: 621 units
#  Store 12: 75 units
#  Store 13: 3896 units
#  Store 14: 397 units
#  Store 15: 354 units
#  Store 16: 296 units
#  Store 17: 1327 units
#  Store 18: 104 units
#  Store 19: 6587 units
#  Store 20: 4209 units
#  Store 21: 144 units
#  Store 22: 192 units
#  Store 23: 6773 units
#  Store 24: 1365 units
#  Store 25: 34529 units
#  Store 26: 2280 units
#  Store 27: 635 units
#  Store 28: 91 units
#  Store 29: 71 units
#  Store 30: 146 units
#  Store 31: 31799 units
#  Store 32: 71 units
#  Store 33: 5056 units
#  Store 34: 94 units
#  Store 35: 11733 units
#  Store 36: 7515 units
#  Store 37: 4659 units
#  Store 38: 912 units
#  Store 39: 1357 units
#  Store 40: 50858 units
#  Store 41: 321 units
#  Store 42: 76 units
#  Store 43: 334 units
#  Store 44: 230 units
#  Store 45: 72 units
#  Store 46: 3816 units
#  Store 47: 483 units
#  Store 48: 257 units
#  Store 49: 104 units
#  Store 50: 939 units
#  Store 51: 88 units
#  Store 52: 6006 units
#  Store 53: 4268 units
#  Store 54: 135 units
#
# MILP for POULTRY on 2017-08-16
# Vehicles needed (MILP): 4
# Shipments:
#  Store 1: 147 units
#  Store 2: 1448 units
#  Store 3: 294 units
#  Store 4: 5651 units
#  Store 5: 513 units
#  Store 6: 135 units
#  Store 7: 43 units
#  Store 8: 31 units
#  Store 9: 74 units
#  Store 10: 14179 units
#  Store 11: 31 units
#  Store 12: 2085 units
#  Store 13: 53 units
#  Store 14: 3929 units
#  Store 15: 3499 units
#  Store 16: 1214 units
#  Store 17: 613 units
#  Store 18: 439 units
#  Store 19: 16617 units
#  Store 20: 154 units
#  Store 21: 32 units
#  Store 22: 210 units
#  Store 23: 223 units
#  Store 24: 31 units
#  Store 25: 1130 units
#  Store 26: 217 units
#  Store 27: 125 units
#  Store 28: 206 units
#  Store 29: 424 units
#  Store 30: 41 units
#  Store 31: 1730 units
#  Store 32: 1266 units
#  Store 33: 61 units
#  Store 34: 84 units
#  Store 35: 2098 units
#  Store 36: 433 units
#  Store 37: 11626 units
#  Store 38: 616 units
#  Store 39: 206 units
#  Store 40: 33 units
#  Store 41: 25 units
#  Store 42: 49 units
#  Store 43: 7723 units
#  Store 44: 25 units
#  Store 45: 1411 units
#  Store 46: 35 units
#  Store 47: 3393 units
#  Store 48: 2073 units
#  Store 49: 1131 units
#  Store 50: 256 units
#  Store 51: 381 units
#  Store 52: 13221 units
#  Store 53: 119 units
#  Store 54: 25 units
#
# MILP for PREPARED FOODS on 2017-08-16
# Vehicles needed (MILP): 3
# Shipments:
#  Store 1: 70 units
#  Store 2: 166 units
#  Store 3: 25 units
#  Store 4: 1067 units
#  Store 5: 137 units
#  Store 6: 36 units
#  Store 7: 41 units
#  Store 8: 291 units
#  Store 9: 29 units
#  Store 10: 1762 units
#  Store 11: 1459 units
#  Store 12: 36 units
#  Store 13: 62 units
#  Store 14: 1595 units
#  Store 15: 226 units
#  Store 16: 4204 units
#  Store 17: 511 units
#  Store 18: 49 units
#  Store 19: 33 units
#  Store 20: 26 units
#  Store 21: 36 units
#  Store 22: 11346 units
#  Store 23: 26 units
#  Store 24: 2136 units
#  Store 25: 45 units
#  Store 26: 2974 units
#  Store 27: 3429 units
#  Store 28: 890 units
#  Store 29: 892 units
#  Store 30: 605 units
#  Store 31: 13112 units
#  Store 32: 196 units
#  Store 33: 27 units
#  Store 34: 150 units
#  Store 35: 198 units
#  Store 36: 26 units
#  Store 37: 924 units
#  Store 38: 84 units
#  Store 39: 84 units
#  Store 40: 43 units
#  Store 41: 436 units
#  Store 42: 37 units
#  Store 43: 1704 units
#  Store 44: 995 units
#  Store 45: 39 units
#  Store 46: 65 units
#  Store 47: 1941 units
#  Store 48: 445 units
#  Store 49: 15704 units
#  Store 50: 460 units
#  Store 51: 220 units
#  Store 52: 29 units
#  Store 53: 23 units
#  Store 54: 34 units
#
# MILP for PRODUCE on 2017-08-16
# Vehicles needed (MILP): 3
# Shipments:
#  Store 1: 7904 units
#  Store 2: 23 units
#  Store 3: 1034 units
#  Store 4: 58 units
#  Store 5: 2870 units
#  Store 6: 1955 units
#  Store 7: 934 units
#  Store 8: 247 units
#  Store 9: 317 units
#  Store 10: 11591 units
#  Store 11: 248 units
#  Store 12: 24 units
#  Store 13: 159 units
#  Store 14: 74 units
#  Store 15: 23 units
#  Store 16: 796 units
#  Store 17: 66 units
#  Store 18: 32 units
#  Store 19: 25 units
#  Store 20: 287 units
#  Store 21: 28 units
#  Store 22: 1159 units
#  Store 23: 954 units
#  Store 24: 30 units
#  Store 25: 42 units
#  Store 26: 781 units
#  Store 27: 209 units
#  Store 28: 4768 units
#  Store 29: 498 units
#  Store 30: 36 units
#  Store 31: 20 units
#  Store 32: 18 units
#  Store 33: 20 units
#  Store 34: 8077 units
#  Store 35: 18 units
#  Store 36: 1683 units
#  Store 37: 21 units
#  Store 38: 2637 units
#  Store 39: 2761 units
#  Store 40: 518 units
#  Store 41: 686 units
#  Store 42: 527 units
#  Store 43: 9358 units
#  Store 44: 79 units
#  Store 45: 18 units
#  Store 46: 41 units
#  Store 47: 77 units
#  Store 48: 18 units
#  Store 49: 638 units
#  Store 50: 19 units
#  Store 51: 91 units
#  Store 52: 20 units
#  Store 53: 337 units
#  Store 54: 22 units
#
# MILP for SCHOOL AND OFFICE SUPPLIES on 2017-08-16
# Vehicles needed (MILP): 7
# Shipments:
#  Store 1: 3936 units
#  Store 2: 1706 units
#  Store 3: 69 units
#  Store 4: 58 units
#  Store 5: 6358 units
#  Store 6: 722 units
#  Store 7: 29819 units
#  Store 8: 51 units
#  Store 9: 218 units
#  Store 10: 74 units
#  Store 11: 57 units
#  Store 12: 76 units
#  Store 13: 25290 units
#  Store 14: 57 units
#  Store 15: 4824 units
#  Store 16: 77 units
#  Store 17: 7970 units
#  Store 18: 6330 units
#  Store 19: 2105 units
#  Store 20: 1288 units
#  Store 21: 1960 units
#  Store 22: 32954 units
#  Store 23: 327 units
#  Store 24: 62 units
#  Store 25: 358 units
#  Store 26: 345 units
#  Store 27: 58 units
#  Store 28: 2180 units
#  Store 29: 70 units
#  Store 30: 449 units
#  Store 31: 73 units
#  Store 32: 1384 units
#  Store 33: 74 units
#  Store 34: 3149 units
#  Store 35: 2122 units
#  Store 36: 81 units
#  Store 37: 104 units
#  Store 38: 2996 units
#  Store 39: 756 units
#  Store 40: 27740 units
#  Store 41: 69 units
#  Store 42: 78 units
#  Store 43: 46 units
#  Store 44: 40 units
#  Store 45: 44 units
#  Store 46: 12339 units
#  Store 47: 40 units
#  Store 48: 2790 units
#  Store 49: 45 units
#  Store 50: 5604 units
#  Store 51: 3007 units
#  Store 52: 1298 units
#  Store 53: 564 units
#  Store 54: 751 units
#
# MILP for SEAFOOD on 2017-08-16
# Vehicles needed (MILP): 2
# Shipments:
#  Store 1: 5639 units
#  Store 2: 21 units
#  Store 3: 16 units
#  Store 4: 33 units
#  Store 5: 32 units
#  Store 6: 16 units
#  Store 7: 413 units
#  Store 8: 18 units
#  Store 9: 21 units
#  Store 10: 18 units
#  Store 11: 228 units
#  Store 12: 17 units
#  Store 13: 671 units
#  Store 14: 445 units
#  Store 15: 17 units
#  Store 16: 18 units
#  Store 17: 386 units
#  Store 18: 147 units
#  Store 19: 5137 units
#  Store 20: 17 units
#  Store 21: 18 units
#  Store 22: 16 units
#  Store 23: 14 units
#  Store 24: 15 units
#  Store 25: 6677 units
#  Store 26: 14 units
#  Store 27: 424 units
#  Store 28: 15 units
#  Store 29: 1960 units
#  Store 30: 462 units
#  Store 31: 433 units
#  Store 32: 138 units
#  Store 33: 47 units
#  Store 34: 6107 units
#  Store 35: 18 units
#  Store 36: 15 units
#  Store 37: 31 units
#  Store 38: 18 units
#  Store 39: 14 units
#  Store 40: 418 units
#  Store 41: 14 units
#  Store 42: 15 units
#  Store 43: 15 units
#  Store 44: 34 units
#  Store 45: 15 units
#  Store 46: 86 units
#  Store 47: 366 units
#  Store 48: 14 units
#  Store 49: 15 units
#  Store 50: 114 units
#  Store 51: 169 units
#  Store 52: 1424 units
#  Store 53: 15 units
#  Store 54: 15 units
#
# MILP for BREAD/BAKERY on 2017-08-18
# Vehicles needed (MILP): 2
# Shipments:
#  Store 1: 26 units
#  Store 2: 3412 units
#  Store 3: 1634 units
#  Store 4: 1246 units
#  Store 5: 468 units
#  Store 6: 250 units
#  Store 7: 12602 units
#  Store 8: 27 units
#  Store 9: 20 units
#  Store 10: 77 units
#  Store 11: 86 units
#  Store 12: 20 units
#  Store 13: 878 units
#  Store 14: 24 units
#  Store 15: 24 units
#  Store 16: 30 units
#  Store 17: 161 units
#  Store 18: 21 units
#  Store 19: 772 units
#  Store 20: 1010 units
#  Store 21: 23 units
#  Store 22: 23 units
#  Store 23: 951 units
#  Store 24: 271 units
#  Store 25: 2751 units
#  Store 26: 284 units
#  Store 27: 29 units
#  Store 28: 14 units
#  Store 29: 14 units
#  Store 30: 14 units
#  Store 31: 2940 units
#  Store 32: 14 units
#  Store 33: 262 units
#  Store 34: 15 units
#  Store 35: 1973 units
#  Store 36: 660 units
#  Store 37: 566 units
#  Store 38: 90 units
#  Store 39: 62 units
#  Store 40: 4963 units
#  Store 41: 16 units
#  Store 42: 15 units
#  Store 43: 18 units
#  Store 44: 18 units
#  Store 45: 14 units
#  Store 46: 439 units
#  Store 47: 15 units
#  Store 48: 16 units
#  Store 49: 15 units
#  Store 50: 25 units
#  Store 51: 15 units
#  Store 52: 488 units
#  Store 53: 469 units
#  Store 54: 15 units
#
# MILP for DAIRY on 2017-08-18
# Vehicles needed (MILP): 2
# Shipments:
#  Store 1: 3545 units
#  Store 2: 16 units
#  Store 3: 401 units
#  Store 4: 19 units
#  Store 5: 2895 units
#  Store 6: 842 units
#  Store 7: 587 units
#  Store 8: 60 units
#  Store 9: 74 units
#  Store 10: 6422 units
#  Store 11: 19 units
#  Store 12: 16 units
#  Store 13: 20 units
#  Store 14: 28 units
#  Store 15: 16 units
#  Store 16: 493 units
#  Store 17: 17 units
#  Store 18: 18 units
#  Store 19: 17 units
#  Store 20: 26 units
#  Store 21: 17 units
#  Store 22: 604 units
#  Store 23: 581 units
#  Store 24: 17 units
#  Store 25: 18 units
#  Store 26: 202 units
#  Store 27: 225 units
#  Store 28: 988 units
#  Store 29: 25 units
#  Store 30: 18 units
#  Store 31: 18 units
#  Store 32: 17 units
#  Store 33: 19 units
#  Store 34: 3338 units
#  Store 35: 17 units
#  Store 36: 361 units
#  Store 37: 19 units
#  Store 38: 1823 units
#  Store 39: 739 units
#  Store 40: 579 units
#  Store 41: 250 units
#  Store 42: 164 units
#  Store 43: 5200 units
#  Store 44: 21 units
#  Store 45: 18 units
#  Store 46: 24 units
#  Store 47: 28 units
#  Store 48: 18 units
#  Store 49: 507 units
#  Store 50: 20 units
#  Store 51: 19 units
#  Store 52: 20 units
#  Store 53: 35 units
#  Store 54: 18 units
#
# MILP for DELI on 2017-08-18
# Vehicles needed (MILP): 1
# Shipments:
#  Store 1: 316 units
#  Store 2: 453 units
#  Store 3: 18 units
#  Store 4: 20 units
#  Store 5: 275 units
#  Store 6: 68 units
#  Store 7: 1238 units
#  Store 8: 33 units
#  Store 9: 19 units
#  Store 10: 14 units
#  Store 11: 13 units
#  Store 12: 14 units
#  Store 13: 2733 units
#  Store 14: 14 units
#  Store 15: 383 units
#  Store 16: 15 units
#  Store 17: 1941 units
#  Store 18: 560 units
#  Store 19: 453 units
#  Store 20: 409 units
#  Store 21: 61 units
#  Store 22: 4153 units
#  Store 23: 16 units
#  Store 24: 14 units
#  Store 25: 22 units
#  Store 26: 25 units
#  Store 27: 14 units
#  Store 28: 439 units
#  Store 29: 14 units
#  Store 30: 16 units
#  Store 31: 15 units
#  Store 32: 44 units
#  Store 33: 14 units
#  Store 34: 114 units
#  Store 35: 340 units
#  Store 36: 14 units
#  Store 37: 15 units
#  Store 38: 131 units
#  Store 39: 37 units
#  Store 40: 1165 units
#  Store 41: 16 units
#  Store 42: 14 units
#  Store 43: 20 units
#  Store 44: 18 units
#  Store 45: 20 units
#  Store 46: 6614 units
#  Store 47: 18 units
#  Store 48: 689 units
#  Store 49: 20 units
#  Store 50: 2466 units
#  Store 51: 1568 units
#  Store 52: 1166 units
#  Store 53: 473 units
#  Store 54: 261 units
#
# MILP for EGGS on 2017-08-18
# Vehicles needed (MILP): 2
# Shipments:
#  Store 1: 9408 units
#  Store 2: 26 units
#  Store 3: 18 units
#  Store 4: 28 units
#  Store 5: 33 units
#  Store 6: 18 units
#  Store 7: 630 units
#  Store 8: 18 units
#  Store 9: 19 units
#  Store 10: 28 units
#  Store 11: 88 units
#  Store 12: 19 units
#  Store 13: 562 units
#  Store 14: 638 units
#  Store 15: 19 units
#  Store 16: 21 units
#  Store 17: 809 units
#  Store 18: 129 units
#  Store 19: 2647 units
#  Store 20: 41 units
#  Store 21: 23 units
#  Store 22: 19 units
#  Store 23: 18 units
#  Store 24: 22 units
#  Store 25: 4431 units
#  Store 26: 18 units
#  Store 27: 1256 units
#  Store 28: 21 units
#  Store 29: 1342 units
#  Store 30: 1323 units
#  Store 31: 514 units
#  Store 32: 450 units
#  Store 33: 150 units
#  Store 34: 5671 units
#  Store 35: 25 units
#  Store 36: 18 units
#  Store 37: 34 units
#  Store 38: 30 units
#  Store 39: 18 units
#  Store 40: 503 units
#  Store 41: 22 units
#  Store 42: 22 units
#  Store 43: 24 units
#  Store 44: 144 units
#  Store 45: 19 units
#  Store 46: 289 units
#  Store 47: 447 units
#  Store 48: 19 units
#  Store 49: 21 units
#  Store 50: 466 units
#  Store 51: 117 units
#  Store 52: 3076 units
#  Store 53: 154 units
#  Store 54: 25 units
#
# MILP for MEATS on 2017-08-18
# Vehicles needed (MILP): 2
# Shipments:
#  Store 1: 583 units
#  Store 2: 420 units
#  Store 3: 163 units
#  Store 4: 11118 units
#  Store 5: 22 units
#  Store 6: 18 units
#  Store 7: 32 units
#  Store 8: 31 units
#  Store 9: 17 units
#  Store 10: 881 units
#  Store 11: 17 units
#  Store 12: 18 units
#  Store 13: 20 units
#  Store 14: 71 units
#  Store 15: 18 units
#  Store 16: 331 units
#  Store 17: 652 units
#  Store 18: 18 units
#  Store 19: 21 units
#  Store 20: 459 units
#  Store 21: 115 units
#  Store 22: 2299 units
#  Store 23: 18 units
#  Store 24: 19 units
#  Store 25: 18 units
#  Store 26: 16 units
#  Store 27: 19 units
#  Store 28: 5098 units
#  Store 29: 16 units
#  Store 30: 1139 units
#  Store 31: 19 units
#  Store 32: 2572 units
#  Store 33: 1586 units
#  Store 34: 539 units
#  Store 35: 324 units
#  Store 36: 363 units
#  Store 37: 7796 units
#  Store 38: 63 units
#  Store 39: 16 units
#  Store 40: 26 units
#  Store 41: 45 units
#  Store 42: 16 units
#  Store 43: 593 units
#  Store 44: 23 units
#  Store 45: 25 units
#  Store 46: 18 units
#  Store 47: 308 units
#  Store 48: 19 units
#  Store 49: 605 units
#  Store 50: 880 units
#  Store 51: 20 units
#  Store 52: 19 units
#  Store 53: 513 units
#  Store 54: 139 units
#
# MILP for POULTRY on 2017-08-18
# Vehicles needed (MILP): 5
# Shipments:
#  Store 1: 157 units
#  Store 2: 1959 units
#  Store 3: 384 units
#  Store 4: 5776 units
#  Store 5: 721 units
#  Store 6: 143 units
#  Store 7: 40 units
#  Store 8: 33 units
#  Store 9: 80 units
#  Store 10: 20298 units
#  Store 11: 33 units
#  Store 12: 2579 units
#  Store 13: 58 units
#  Store 14: 4703 units
#  Store 15: 4300 units
#  Store 16: 1618 units
#  Store 17: 928 units
#  Store 18: 582 units
#  Store 19: 21672 units
#  Store 20: 166 units
#  Store 21: 34 units
#  Store 22: 246 units
#  Store 23: 264 units
#  Store 24: 33 units
#  Store 25: 1581 units
#  Store 26: 257 units
#  Store 27: 136 units
#  Store 28: 241 units
#  Store 29: 565 units
#  Store 30: 41 units
#  Store 31: 2526 units
#  Store 32: 1714 units
#  Store 33: 66 units
#  Store 34: 89 units
#  Store 35: 2664 units
#  Store 36: 569 units
#  Store 37: 12007 units
#  Store 38: 836 units
#  Store 39: 241 units
#  Store 40: 35 units
#  Store 41: 26 units
#  Store 42: 53 units
#  Store 43: 10758 units
#  Store 44: 26 units
#  Store 45: 1913 units
#  Store 46: 38 units
#  Store 47: 4421 units
#  Store 48: 2828 units
#  Store 49: 1574 units
#  Store 50: 309 units
#  Store 51: 542 units
#  Store 52: 18644 units
#  Store 53: 125 units
#  Store 54: 27 units
#
# MILP for PREPARED FOODS on 2017-08-18
# Vehicles needed (MILP): 3
# Shipments:
#  Store 1: 73 units
#  Store 2: 182 units
#  Store 3: 27 units
#  Store 4: 1475 units
#  Store 5: 145 units
#  Store 6: 39 units
#  Store 7: 40 units
#  Store 8: 377 units
#  Store 9: 31 units
#  Store 10: 2646 units
#  Store 11: 1990 units
#  Store 12: 39 units
#  Store 13: 66 units
#  Store 14: 2186 units
#  Store 15: 268 units
#  Store 16: 4776 units
#  Store 17: 715 units
#  Store 18: 53 units
#  Store 19: 36 units
#  Store 20: 27 units
#  Store 21: 39 units
#  Store 22: 14859 units
#  Store 23: 27 units
#  Store 24: 2442 units
#  Store 25: 49 units
#  Store 26: 3443 units
#  Store 27: 4054 units
#  Store 28: 1100 units
#  Store 29: 1132 units
#  Store 30: 824 units
#  Store 31: 15567 units
#  Store 32: 223 units
#  Store 33: 28 units
#  Store 34: 160 units
#  Store 35: 228 units
#  Store 36: 27 units
#  Store 37: 1239 units
#  Store 38: 89 units
#  Store 39: 87 units
#  Store 40: 40 units
#  Store 41: 589 units
#  Store 42: 40 units
#  Store 43: 2142 units
#  Store 44: 1319 units
#  Store 45: 41 units
#  Store 46: 68 units
#  Store 47: 2336 units
#  Store 48: 556 units
#  Store 49: 15057 units
#  Store 50: 569 units
#  Store 51: 257 units
#  Store 52: 31 units
#  Store 53: 24 units
#  Store 54: 37 units
#
# MILP for PRODUCE on 2017-08-18
# Vehicles needed (MILP): 3
# Shipments:
#  Store 1: 10224 units
#  Store 2: 24 units
#  Store 3: 1349 units
#  Store 4: 62 units
#  Store 5: 3505 units
#  Store 6: 2363 units
#  Store 7: 1150 units
#  Store 8: 295 units
#  Store 9: 416 units
#  Store 10: 14366 units
#  Store 11: 297 units
#  Store 12: 25 units
#  Store 13: 170 units
#  Store 14: 77 units
#  Store 15: 24 units
#  Store 16: 1074 units
#  Store 17: 70 units
#  Store 18: 34 units
#  Store 19: 27 units
#  Store 20: 360 units
#  Store 21: 30 units
# ...
#  Store 18: 11 units
#  Store 19: 17 units
#  Store 20: 34 units
#  Store 21: 11 units
#  Store 22: 273 units
#  Store 23: 14 units
#  Store 24: 37 units
#  Store 25: 14 units
#  Store 26: 107 units
#  Store 27: 14 units
#  Store 28: 457 units
#  Store 29: 267 units
#  Store 30: 16 units
#  Store 31: 13 units
#  Store 32: 647 units
#  Store 33: 135 units
#  Store 34: 3017 units
#  Store 35: 12 units
#  Store 36: 19 units
#  Store 37: 8 units
#  Store 38: 8 units
#  Store 39: 8 units
#  Store 40: 1929 units
#  Store 41: 8 units
#  Store 42: 397 units
#  Store 43: 9 units
#  Store 44: 465 units
#  Store 45: 576 units
#  Store 46: 172 units
#  Store 47: 147 units
#  Store 48: 145 units
#  Store 49: 1798 units
#  Store 50: 14 units
#  Store 51: 8 units
#  Store 52: 11 units
#  Store 53: 12 units
#  Store 54: 8 units
#
# MILP for HOME AND KITCHEN I on 2017-08-31
# Vehicles needed (MILP): 1
# Shipments:
#  Store 1: 127 units
#  Store 2: 8 units
#  Store 3: 18 units
#  Store 4: 8 units
#  Store 5: 265 units
#  Store 6: 9 units
#  Store 7: 274 units
#  Store 8: 133 units
#  Store 9: 8 units
#  Store 10: 8 units
#  Store 11: 215 units
#  Store 12: 23 units
#  Store 13: 1312 units
#  Store 14: 8 units
#  Store 15: 9 units
#  Store 16: 10 units
#  Store 17: 9 units
#  Store 18: 10 units
#  Store 19: 759 units
#  Store 20: 11 units
#  Store 21: 209 units
#  Store 22: 14 units
#  Store 23: 330 units
#  Store 24: 222 units
#  Store 25: 90 units
#  Store 26: 37 units
#  Store 27: 21 units
#  Store 28: 1197 units
#  Store 29: 17 units
#  Store 30: 13 units
#  Store 31: 16 units
#  Store 32: 16 units
#  Store 33: 13 units
#  Store 34: 78 units
#  Store 35: 13 units
#  Store 36: 16 units
#  Store 37: 13 units
#  Store 38: 21 units
#  Store 39: 12 units
#  Store 40: 291 units
#  Store 41: 145 units
#  Store 42: 13 units
#  Store 43: 13 units
#  Store 44: 168 units
#  Store 45: 19 units
#  Store 46: 487 units
#  Store 47: 14 units
#  Store 48: 14 units
#  Store 49: 12 units
#  Store 50: 10 units
#  Store 51: 12 units
#  Store 52: 2760 units
#  Store 53: 10 units
#  Store 54: 516 units
#
# MILP for HOME AND KITCHEN II on 2017-08-31
# Vehicles needed (MILP): 1
# Shipments:
#  Store 1: 15 units
#  Store 2: 720 units
#  Store 3: 740 units
#  Store 4: 307 units
#  Store 5: 233 units
#  Store 6: 159 units
#  Store 7: 3202 units
#  Store 8: 21 units
#  Store 9: 11 units
#  Store 10: 15 units
#  Store 11: 29 units
#  Store 12: 11 units
#  Store 13: 231 units
#  Store 14: 12 units
#  Store 15: 40 units
#  Store 16: 13 units
#  Store 17: 198 units
#  Store 18: 11 units
#  Store 19: 303 units
#  Store 20: 241 units
#  Store 21: 13 units
#  Store 22: 13 units
#  Store 23: 364 units
#  Store 24: 90 units
#  Store 25: 2031 units
#  Store 26: 11 units
#  Store 27: 17 units
#  Store 28: 10 units
#  Store 29: 9 units
#  Store 30: 10 units
#  Store 31: 2936 units
#  Store 32: 10 units
#  Store 33: 460 units
#  Store 34: 12 units
#  Store 35: 856 units
#  Store 36: 601 units
#  Store 37: 337 units
#  Store 38: 238 units
#  Store 39: 72 units
#  Store 40: 3911 units
#  Store 41: 13 units
#  Store 42: 10 units
#  Store 43: 22 units
#  Store 44: 16 units
#  Store 45: 10 units
#  Store 46: 224 units
#  Store 47: 10 units
#  Store 48: 11 units
#  Store 49: 11 units
#  Store 50: 58 units
#  Store 51: 10 units
#  Store 52: 245 units
#  Store 53: 283 units
#  Store 54: 10 units
#
# MILP for HOME APPLIANCES on 2017-08-31
# Vehicles needed (MILP): 1
# Shipments:
#  Store 1: 10 units
#  Store 2: 217 units
#  Store 3: 84 units
#  Store 4: 1230 units
#  Store 5: 11 units
#  Store 6: 11 units
#  Store 7: 10 units
#  Store 8: 9 units
#  Store 9: 10 units
#  Store 10: 2939 units
#  Store 11: 9 units
#  Store 12: 494 units
#  Store 13: 12 units
#  Store 14: 757 units
#  Store 15: 509 units
#  Store 16: 260 units
#  Store 17: 226 units
#  Store 18: 91 units
#  Store 19: 3265 units
#  Store 20: 13 units
#  Store 21: 10 units
#  Store 22: 18 units
#  Store 23: 16 units
#  Store 24: 10 units
#  Store 25: 241 units
#  Store 26: 10 units
#  Store 27: 11 units
#  Store 28: 10 units
#  Store 29: 123 units
#  Store 30: 10 units
#  Store 31: 138 units
#  Store 32: 234 units
#  Store 33: 10 units
#  Store 34: 10 units
#  Store 35: 202 units
#  Store 36: 60 units
#  Store 37: 913 units
#  Store 38: 10 units
#  Store 39: 11 units
#  Store 40: 8 units
#  Store 41: 7 units
#  Store 42: 8 units
#  Store 43: 1114 units
#  Store 44: 8 units
#  Store 45: 163 units
#  Store 46: 9 units
#  Store 47: 884 units
#  Store 48: 245 units
#  Store 49: 138 units
#  Store 50: 160 units
#  Store 51: 43 units
#  Store 52: 2294 units
#  Store 53: 10 units
#  Store 54: 8 units
#
# MILP for HOME CARE on 2017-08-31
# Vehicles needed (MILP): 1
# Shipments:
#  Store 1: 16 units
#  Store 2: 13 units
#  Store 3: 8 units
#  Store 4: 187 units
#  Store 5: 8 units
#  Store 6: 10 units
#  Store 7: 9 units
#  Store 8: 30 units
#  Store 9: 8 units
#  Store 10: 62 units
#  Store 11: 103 units
#  Store 12: 9 units
#  Store 13: 9 units
#  Store 14: 120 units
#  Store 15: 19 units
#  Store 16: 469 units
#  Store 17: 10 units
#  Store 18: 10 units
#  Store 19: 11 units
#  Store 20: 10 units
#  Store 21: 10 units
#  Store 22: 3051 units
#  Store 23: 10 units
#  Store 24: 491 units
#  Store 25: 12 units
#  Store 26: 1017 units
#  Store 27: 519 units
#  Store 28: 239 units
#  Store 29: 313 units
#  Store 30: 101 units
#  Store 31: 3920 units
#  Store 32: 14 units
#  Store 33: 10 units
#  Store 34: 16 units
#  Store 35: 17 units
#  Store 36: 10 units
#  Store 37: 275 units
#  Store 38: 10 units
#  Store 39: 12 units
#  Store 40: 12 units
#  Store 41: 18 units
#  Store 42: 10 units
#  Store 43: 650 units
#  Store 44: 247 units
#  Store 45: 11 units
#  Store 46: 11 units
#  Store 47: 143 units
#  Store 48: 62 units
#  Store 49: 1031 units
#  Store 50: 11 units
#  Store 51: 11 units
#  Store 52: 8 units
#  Store 53: 7 units
#  Store 54: 8 units
#
# MILP for LADIESWEAR on 2017-08-31
# Vehicles needed (MILP): 1
# Shipments:
#  Store 1: 919 units
#  Store 2: 8 units
#  Store 3: 133 units
#  Store 4: 10 units
#  Store 5: 838 units
#  Store 6: 184 units
#  Store 7: 103 units
#  Store 8: 197 units
#  Store 9: 18 units
#  Store 10: 1972 units
#  Store 11: 9 units
#  Store 12: 8 units
#  Store 13: 14 units
#  Store 14: 11 units
#  Store 15: 8 units
#  Store 16: 83 units
#  Store 17: 8 units
#  Store 18: 10 units
#  Store 19: 9 units
#  Store 20: 22 units
#  Store 21: 8 units
#  Store 22: 64 units
#  Store 23: 63 units
#  Store 24: 9 units
#  Store 25: 9 units
#  Store 26: 49 units
#  Store 27: 15 units
#  Store 28: 243 units
#  Store 29: 10 units
#  Store 30: 9 units
#  Store 31: 10 units
#  Store 32: 8 units
#  Store 33: 9 units
#  Store 34: 2490 units
#  Store 35: 8 units
#  Store 36: 217 units
#  Store 37: 11 units
#  Store 38: 1116 units
#  Store 39: 427 units
#  Store 40: 203 units
#  Store 41: 204 units
#  Store 42: 61 units
#  Store 43: 3216 units
#  Store 44: 9 units
#  Store 45: 8 units
#  Store 46: 23 units
#  Store 47: 16 units
#  Store 48: 8 units
#  Store 49: 227 units
#  Store 50: 8 units
#  Store 51: 9 units
#  Store 52: 13 units
#  Store 53: 33 units
#  Store 54: 9 units
#
# MILP for LAWN AND GARDEN on 2017-08-31
# Vehicles needed (MILP): 1
# Shipments:
#  Store 1: 250 units
#  Store 2: 214 units
#  Store 3: 9 units
#  Store 4: 9 units
#  Store 5: 222 units
#  Store 6: 22 units
#  Store 7: 935 units
#  Store 8: 9 units
#  Store 9: 9 units
#  Store 10: 12 units
#  Store 11: 11 units
#  Store 12: 11 units
#  Store 13: 2063 units
#  Store 14: 11 units
#  Store 15: 561 units
#  Store 16: 13 units
#  Store 17: 792 units
#  Store 18: 540 units
#  Store 19: 255 units
#  Store 20: 136 units
#  Store 21: 61 units
#  Store 22: 3710 units
#  Store 23: 14 units
#  Store 24: 12 units
#  Store 25: 21 units
#  Store 26: 34 units
#  Store 27: 11 units
#  Store 28: 214 units
#  Store 29: 11 units
#  Store 30: 14 units
#  Store 31: 12 units
#  Store 32: 28 units
#  Store 33: 12 units
#  Store 34: 226 units
#  Store 35: 247 units
#  Store 36: 12 units
#  Store 37: 12 units
#  Store 38: 152 units
#  Store 39: 24 units
#  Store 40: 605 units
#  Store 41: 13 units
#  Store 42: 12 units
#  Store 43: 7 units
#  Store 44: 7 units
#  Store 45: 7 units
#  Store 46: 1164 units
#  Store 47: 7 units
#  Store 48: 107 units
#  Store 49: 8 units
#  Store 50: 422 units
#  Store 51: 191 units
#  Store 52: 109 units
#  Store 53: 169 units
#  Store 54: 46 units
#
# MILP for LINGERIE on 2017-08-31
# Vehicles needed (MILP): 1
# Shipments:
#  Store 1: 1930 units
#  Store 2: 9 units
#  Store 3: 7 units
#  Store 4: 10 units
#  Store 5: 10 units
#  Store 6: 7 units
#  Store 7: 104 units
#  Store 8: 7 units
#  Store 9: 8 units
#  Store 10: 8 units
#  Store 11: 46 units
#  Store 12: 7 units
#  Store 13: 204 units
#  Store 14: 81 units
#  Store 15: 7 units
#  Store 16: 7 units
#  Store 17: 47 units
#  Store 18: 15 units
#  Store 19: 405 units
#  Store 20: 8 units
#  Store 21: 8 units
#  Store 22: 10 units
#  Store 23: 9 units
#  Store 24: 9 units
#  Store 25: 3030 units
#  Store 26: 9 units
#  Store 27: 487 units
#  Store 28: 11 units
#  Store 29: 729 units
#  Store 30: 513 units
#  Store 31: 226 units
#  Store 32: 146 units
#  Store 33: 127 units
#  Store 34: 3408 units
#  Store 35: 11 units
#  Store 36: 9 units
#  Store 37: 22 units
#  Store 38: 13 units
#  Store 39: 9 units
#  Store 40: 223 units
#  Store 41: 9 units
#  Store 42: 23 units
#  Store 43: 10 units
#  Store 44: 64 units
#  Store 45: 10 units
#  Store 46: 320 units
#  Store 47: 223 units
#  Store 48: 10 units
#  Store 49: 10 units
#  Store 50: 140 units
#  Store 51: 38 units
#  Store 52: 1050 units
#  Store 53: 10 units
#  Store 54: 10 units
#
# MILP for LIQUOR,WINE,BEER on 2017-08-31
# Vehicles needed (MILP): 1
# Shipments:
#  Store 1: 10 units
#  Store 2: 10 units
#  Store 3: 13 units
#  Store 4: 2983 units
#  Store 5: 10 units
#  Store 6: 543 units
#  Store 7: 11 units
#  Store 8: 939 units
#  Store 9: 918 units
#  Store 10: 184 units
#  Store 11: 136 units
#  Store 12: 130 units
#  Store 13: 3699 units
#  Store 14: 52 units
#  Store 15: 10 units
#  Store 16: 20 units
#  Store 17: 23 units
#  Store 18: 10 units
#  Store 19: 259 units
#  Store 20: 16 units
#  Store 21: 19 units
#  Store 22: 11 units
#  Store 23: 130 units
#  Store 24: 12 units
#  Store 25: 270 units
#  Store 26: 294 units
#  Store 27: 13 units
#  Store 28: 13 units
#  Store 29: 279 units
#  Store 30: 64 units
#  Store 31: 1900 units
#  Store 32: 11 units
#  Store 33: 13 units
#  Store 34: 11 units
#  Store 35: 10 units
#  Store 36: 13 units
#  Store 37: 2214 units
#  Store 38: 10 units
#  Store 39: 393 units
#  Store 40: 13 units
#  Store 41: 719 units
#  Store 42: 611 units
#  Store 43: 169 units
#  Store 44: 101 units
#  Store 45: 124 units
#  Store 46: 3255 units
#  Store 47: 20 units
#  Store 48: 11 units
#  Store 49: 31 units
#  Store 50: 60 units
#  Store 51: 10 units
#  Store 52: 273 units
#  Store 53: 16 units
#  Store 54: 16 units
#
# MILP for MAGAZINES on 2017-08-31
# Vehicles needed (MILP): 1
# Shipments:
#  Store 1: 13 units
#  Store 2: 126 units
#  Store 3: 13 units
#  Store 4: 174 units
#  Store 5: 360 units
#  Store 6: 12 units
#  Store 7: 13 units
#  Store 8: 140 units
#  Store 9: 88 units
#  Store 10: 1652 units
#  Store 11: 12 units
#  Store 12: 16 units
#  Store 13: 12 units
#  Store 14: 10 units
#  Store 15: 12 units
#  Store 16: 3200 units
#  Store 17: 10 units
#  Store 18: 574 units
#  Store 19: 11 units
#  Store 20: 1322 units
#  Store 21: 513 units
#  Store 22: 212 units
#  Store 23: 295 units
#  Store 24: 63 units
#  Store 25: 4537 units
#  Store 26: 25 units
#  Store 27: 10 units
#  Store 28: 16 units
#  Store 29: 16 units
#  Store 30: 10 units
#  Store 31: 326 units
#  Store 32: 11 units
#  Store 33: 14 units
#  Store 34: 13 units
#  Store 35: 58 units
#  Store 36: 11 units
#  Store 37: 183 units
#  Store 38: 308 units
#  Store 39: 11 units
#  Store 40: 12 units
#  Store 41: 240 units
#  Store 42: 51 units
#  Store 43: 1203 units
#  Store 44: 19 units
#  Store 45: 14 units
#  Store 46: 10 units
#  Store 47: 10 units
#  Store 48: 11 units
#  Store 49: 4270 units
#  Store 50: 10 units
#  Store 51: 404 units
#  Store 52: 12 units
#  Store 53: 1542 units
#  Store 54: 577 units
#
# MILP for PERSONAL CARE on 2017-08-31
# Vehicles needed (MILP): 1
# Shipments:
#  Store 1: 1654 units
#  Store 2: 10 units
#  Store 3: 10 units
#  Store 4: 10 units
#  Store 5: 10 units
#  Store 6: 11 units
#  Store 7: 2200 units
#  Store 8: 10 units
#  Store 9: 410 units
#  Store 10: 12 units
#  Store 11: 659 units
#  Store 12: 718 units
#  Store 13: 192 units
#  Store 14: 145 units
#  Store 15: 132 units
#  Store 16: 2700 units
#  Store 17: 23 units
#  Store 18: 10 units
#  Store 19: 20 units
#  Store 20: 20 units
#  Store 21: 10 units
#  Store 22: 207 units
#  Store 23: 13 units
#  Store 24: 43 units
#  Store 25: 12 units
#  Store 26: 72 units
#  Store 27: 12 units
#  Store 28: 234 units
#  Store 29: 229 units
#  Store 30: 12 units
#  Store 31: 12 units
#  Store 32: 222 units
#  Store 33: 52 units
#  Store 34: 1771 units
#  Store 35: 11 units
#  Store 36: 14 units
#  Store 37: 11 units
#  Store 38: 10 units
#  Store 39: 11 units
#  Store 40: 4173 units
#  Store 41: 10 units
#  Store 42: 517 units
#  Store 43: 14 units
#  Store 44: 976 units
#  Store 45: 532 units
#  Store 46: 290 units
#  Store 47: 240 units
#  Store 48: 73 units
#  Store 49: 4239 units
#  Store 50: 13 units
#  Store 51: 10 units
#  Store 52: 14 units
#  Store 53: 17 units
#  Store 54: 10 units
#
# MILP for PET SUPPLIES on 2017-08-31
# Vehicles needed (MILP): 2
# Shipments:
#  Store 1: 245 units
#  Store 2: 10 units
#  Store 3: 13 units
#  Store 4: 11 units
#  Store 5: 101 units
#  Store 6: 11 units
#  Store 7: 233 units
#  Store 8: 292 units
#  Store 9: 11 units
#  Store 10: 11 units
#  Store 11: 254 units
#  Store 12: 145 units
#  Store 13: 966 units
#  Store 14: 11 units
#  Store 15: 10 units
#  Store 16: 23 units
#  Store 17: 16 units
#  Store 18: 29 units
#  Store 19: 7159 units
#  Store 20: 16 units
#  Store 21: 1168 units
#  Store 22: 33 units
#  Store 23: 1826 units
#  Store 24: 1753 units
#  Store 25: 536 units
#  Store 26: 490 units
#  Store 27: 407 units
#  Store 28: 7051 units
#  Store 29: 116 units
#  Store 30: 18 units
#  Store 31: 136 units
#  Store 32: 152 units
#  Store 33: 16 units
#  Store 34: 519 units
#  Store 35: 111 units
#  Store 36: 42 units
#  Store 37: 118 units
#  Store 38: 316 units
#  Store 39: 32 units
#  Store 40: 912 units
#  Store 41: 478 units
#  Store 42: 48 units
#  Store 43: 47 units
#  Store 44: 1097 units
#  Store 45: 242 units
#  Store 46: 6514 units
#  Store 47: 265 units
#  Store 48: 124 units
#  Store 49: 24 units
#  Store 50: 18 units
#  Store 51: 34 units
#  Store 52: 6808 units
#  Store 53: 18 units
#  Store 54: 909 units
#
# MILP for PLAYERS AND ELECTRONICS on 2017-08-31
# Vehicles needed (MILP): 2
# Shipments:
#  Store 1: 35 units
#  Store 2: 1831 units
#  Store 3: 1579 units
#  Store 4: 535 units
#  Store 5: 351 units
#  Store 6: 260 units
#  Store 7: 7929 units
#  Store 8: 159 units
#  Store 9: 18 units
#  Store 10: 106 units
#  Store 11: 122 units
#  Store 12: 18 units
#  Store 13: 489 units
#  Store 14: 64 units
#  Store 15: 55 units
#  Store 16: 48 units
#  Store 17: 198 units
#  Store 18: 32 units
#  Store 19: 1144 units
#  Store 20: 541 units
#  Store 21: 34 units
#  Store 22: 43 units
#  Store 23: 932 units
#  Store 24: 225 units
#  Store 25: 4636 units
#  Store 26: 320 units
#  Store 27: 125 units
#  Store 28: 22 units
#  Store 29: 17 units
#  Store 30: 34 units
#  Store 31: 4415 units
#  Store 32: 17 units
#  Store 33: 615 units
#  Store 34: 23 units
#  Store 35: 1617 units
#  Store 36: 1016 units
#  Store 37: 579 units
#  Store 38: 170 units
#  Store 39: 192 units
#  Store 40: 7066 units
#  Store 41: 55 units
#  Store 42: 18 units
#  Store 43: 55 units
#  Store 44: 46 units
#  Store 45: 17 units
#  Store 46: 457 units
#  Store 47: 93 units
#  Store 48: 48 units
#  Store 49: 33 units
#  Store 50: 173 units
#  Store 51: 21 units
#  Store 52: 1011 units
#  Store 53: 507 units
#  Store 54: 32 units
#
# MILP for SCHOOL AND OFFICE SUPPLIES on 2017-08-31
# Vehicles needed (MILP): 1
# Shipments:
#  Store 1: 772 units
#  Store 2: 300 units
#  Store 3: 16 units
#  Store 4: 14 units
#  Store 5: 719 units
#  Store 6: 141 units
#  Store 7: 4279 units
#  Store 8: 12 units
#  Store 9: 47 units
#  Store 10: 18 units
#  Store 11: 13 units
#  Store 12: 18 units
#  Store 13: 4027 units
#  Store 14: 13 units
#  Store 15: 647 units
#  Store 16: 19 units
#  Store 17: 1238 units
#  Store 18: 932 units
#  Store 19: 340 units
#  Store 20: 229 units
#  Store 21: 331 units
#  Store 22: 5158 units
#  Store 23: 55 units
#  Store 24: 15 units
#  Store 25: 57 units
#  Store 26: 56 units
#  Store 27: 14 units
#  Store 28: 302 units
#  Store 29: 17 units
#  Store 30: 70 units
#  Store 31: 18 units
#  Store 32: 204 units
#  Store 33: 18 units
#  Store 34: 578 units
#  Store 35: 306 units
#  Store 36: 20 units
#  Store 37: 30 units
#  Store 38: 518 units
#  Store 39: 147 units
#  Store 40: 3981 units
#  Store 41: 17 units
#  Store 42: 19 units
#  Store 43: 11 units
#  Store 44: 9 units
#  Store 45: 10 units
#  Store 46: 1876 units
#  Store 47: 9 units
#  Store 48: 402 units
#  Store 49: 11 units
#  Store 50: 787 units
#  Store 51: 411 units
#  Store 52: 231 units
#  Store 53: 111 units
#  Store 54: 146 units
#
# No store capacity violations detected.

# %%
# ---- VRP Warehouse to Branch Transportation ----
def split_large_demands(stores, shipment_quantities, vehicle_capacity):
    new_stores = []
    new_demands = []
    for _, store in stores.iterrows():
        store_id = store["Store"]
        demand = shipment_quantities[store_id]
        num_splits = int(np.ceil(demand / vehicle_capacity))
        split_demand = demand / num_splits
        for split_i in range(num_splits):
            split_store = store.copy()
            split_store["SplitID"] = f"{store_id}_{split_i}"
            new_stores.append(split_store)
            new_demands.append(split_demand)
    new_stores_df = pd.DataFrame(new_stores).reset_index(drop=True)
    return new_stores_df, new_demands

def create_distance_matrix(locations):
    size = len(locations)
    dist_matrix = np.zeros((size, size))
    for i in range(size):
        for j in range(size):
            dist_matrix[i][j] = great_circle(locations[i], locations[j]).kilometers
    return dist_matrix

def solve_vrp(distance_matrix, demands, vehicle_capacities, depot=0):
    manager = pywrapcp.RoutingIndexManager(len(distance_matrix), len(vehicle_capacities), depot)
    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_idx, to_idx):
        return int(distance_matrix[manager.IndexToNode(from_idx)][manager.IndexToNode(to_idx)] * 1000)

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    def demand_callback(from_idx):
        return int(demands[manager.IndexToNode(from_idx)])

    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(demand_callback_index, 0, vehicle_capacities, True, "Capacity")

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC
    search_parameters.local_search_metaheuristic = routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH
    search_parameters.time_limit.seconds = 30
    search_parameters.log_search = False

    solution = routing.SolveWithParameters(search_parameters)

    if solution:
        routes = []
        for vehicle_id in range(len(vehicle_capacities)):
            index = routing.Start(vehicle_id)
            route = []
            while not routing.IsEnd(index):
                node = manager.IndexToNode(index)
                route.append(node)
                index = solution.Value(routing.NextVar(index))
            route.append(manager.IndexToNode(index)) 
            routes.append(route)
        return routes
    else:
        return None

for res in milp_results:
    delivery_date = res["DeliveryDate"]
    product_family = res["ProductFamily"]
    stores = res["Stores"]
    shipment_quantities = res["ShipmentQuantities"]
    vehicles_needed = res["VehiclesNeeded"]

    print(f"\nVRP routing for {product_family} on {delivery_date.date()}, Vehicles: {vehicles_needed}")

    filtered_stores = stores[[shipment_quantities[sid] > 0 for sid in stores["Store"]]].reset_index(drop=True)

    filtered_stores, filtered_qty = split_large_demands(filtered_stores, shipment_quantities, vehicle_capacity)

    locations = [warehouse_location] + list(zip(filtered_stores["Latitude"], filtered_stores["Longitude"]))
    demands = [0] + filtered_qty  
    vehicle_capacities = [vehicle_capacity] * vehicles_needed

    dist_matrix = create_distance_matrix(locations)
    routes = solve_vrp(dist_matrix, demands, vehicle_capacities, depot=0)

    if routes is None:
        print("No VRP solution found.")
        continue

    for v, route in enumerate(routes):
        route_store_ids = []
        for i in route:
            if i == 0:
                route_store_ids.append("Depot")
            else:
                route_store_ids.append(filtered_stores.loc[i - 1, "SplitID"])
        print(f" Vehicle {v + 1} route: {route_store_ids}")

    total_route_distance = 0
    for route in routes:
        route_distance = 0
        for i in range(len(route) - 1):
            from_node = route[i]
            to_node = route[i+1]
            route_distance += dist_matrix[from_node][to_node]
        total_route_distance += route_distance

    # Oil price on that date, convert barrel price to liter price (1 barrel = ~159 liters)
    oil_price = oil_prices[oil_prices["date"].dt.date == delivery_date.date()]["OilPrice"].values[0] / 159

    total_cost = total_route_distance * oil_price + fee_per_unit * total_demand

    print(f"Total distance traveled by all vehicles: {total_route_distance:.2f} km")
    print(f"Oil price on {delivery_date.date()}: {oil_price} USD/liter")
    print(f"Total delivery cost for {product_family} on {delivery_date.date()}: {total_cost:.2f} USD")

    m = folium.Map(location=warehouse_location, zoom_start=7)
    folium.Marker(location=warehouse_location, tooltip="Warehouse HQ", icon=folium.Icon(color='red')).add_to(m)

    colors = ['blue', 'green', 'purple', 'orange', 'darkred']
    for v, route in enumerate(routes):
        points = [locations[i] for i in route]
        folium.PolyLine(points, color=colors[v % len(colors)], weight=5, opacity=0.8,
                        tooltip=f"Vehicle {v + 1}").add_to(m)
        for idx in route[1:-1]:
            store = filtered_stores.loc[idx - 1]
            folium.Marker(
                location=(store["Latitude"], store["Longitude"]),
                tooltip=f"Store {store['Store']} Demand: {filtered_qty[idx - 1]:.1f}",
                icon=folium.Icon(color=colors[v % len(colors)], icon='truck', prefix='fa')
            ).add_to(m)

    map_filename = f"{safe_name(product_family)}_Distribution_Transportation_Plan_{delivery_date.date()}.html"
    m.save(f"{folder_name}/{map_filename}")

    print(f"Map saved as {map_filename}")
# Out:
# VRP routing for AUTOMOTIVE on 2017-08-16, Vehicles: 4
#  Vehicle 1 route: ['Depot', '6_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '3_0', '48_0', '17_0', '13_0', 'Depot']
#  Vehicle 2 route: ['Depot', '22_0', '14_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '19_0', '23_0', '50_0', '12_0', 'Depot']
#  Vehicle 3 route: ['Depot', '11_0', '15_0', '43_0', '52_0', '53_0', '25_0', '35_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '30_0', '34_0', '27_0', '36_0', '31_0', '33_0', '54_0', '5_0', '16_0', '21_0', 'Depot']
#  Vehicle 4 route: ['Depot', '20_0', '45_0', '9_0', '44_0', '46_0', 'Depot']
# Total distance traveled by all vehicles: 2363.22 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for AUTOMOTIVE on 2017-08-16: 710.46 USD
# Map saved as AUTOMOTIVE_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for BABY CARE on 2017-08-16, Vehicles: 8
# No VRP solution found.
#
# VRP routing for BEAUTY on 2017-08-16, Vehicles: 3
#  Vehicle 1 route: ['Depot', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
#  Vehicle 2 route: ['Depot', '19_0', '31_0', '41_0', '40_0', '38_0', '39_0', '42_0', '37_0', '14_0', '22_0', 'Depot']
#  Vehicle 3 route: ['Depot', '13_0', '12_0', '50_0', '23_0', '33_0', '36_0', '27_0', '34_0', '30_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '35_0', '25_0', '53_0', '52_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', 'Depot']
# Total distance traveled by all vehicles: 2258.94 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for BEAUTY on 2017-08-16: 679.76 USD
# Map saved as BEAUTY_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for BEVERAGES on 2017-08-16, Vehicles: 6
#  Vehicle 1 route: ['Depot', '21_0', '16_0', '5_0', 'Depot']
#  Vehicle 2 route: ['Depot', '54_0', '33_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '31_0', '19_0', '23_0', '50_0', '12_0', 'Depot']
#  Vehicle 3 route: ['Depot', '13_0', '22_0', '14_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '43_0', 'Depot']
#  Vehicle 4 route: ['Depot', '17_0', '48_0', '2_0', '18_0', '47_0', '7_0', '8_0', '9_0', 'Depot']
#  Vehicle 5 route: ['Depot', '6_0', '20_0', '45_0', '10_0', '4_0', '1_0', '15_0', '11_0', 'Depot']
#  Vehicle 6 route: ['Depot', '44_0', '49_0', '3_0', '46_0', 'Depot']
# Total distance traveled by all vehicles: 2470.77 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for BEVERAGES on 2017-08-16: 742.11 USD
# Map saved as BEVERAGES_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for BOOKS on 2017-08-16, Vehicles: 6
#  Vehicle 1 route: ['Depot', '21_0', '16_0', '5_0', '54_0', '53_0', '52_0', '43_0', 'Depot']
#  Vehicle 2 route: ['Depot', '46_0', '44_0', '17_0', 'Depot']
#  Vehicle 3 route: ['Depot', '50_0', '23_0', '19_0', 'Depot']
#  Vehicle 4 route: ['Depot', '36_0', '30_0', '28_0', '34_0', '27_0', '33_0', 'Depot']
#  Vehicle 5 route: ['Depot', '12_0', '13_0', 'Depot']
#  Vehicle 6 route: ['Depot', '31_0', '24_0', '26_0', '29_0', '51_0', '32_0', '25_0', '35_0', '41_0', '40_0', '38_0', '39_0', '42_0', '37_0', '14_0', '22_0', '11_0', '15_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '3_0', '48_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 3066.94 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for BOOKS on 2017-08-16: 917.59 USD
# Map saved as BOOKS_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for BREAD/BAKERY on 2017-08-16, Vehicles: 2
#  Vehicle 1 route: ['Depot', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', 'Depot']
#  Vehicle 2 route: ['Depot', '11_0', '15_0', '43_0', '21_0', '16_0', '5_0', '54_0', '33_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '42_0', '37_0', '39_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '34_0', '30_0', '27_0', '36_0', '31_0', '19_0', '14_0', '22_0', '50_0', '23_0', '12_0', '13_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for BREAD/BAKERY on 2017-08-16: 573.39 USD
# Map saved as BREAD_BAKERY_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for CELEBRATION on 2017-08-16, Vehicles: 5
#  Vehicle 1 route: ['Depot', '19_0', '31_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '34_0', '30_0', '27_0', '36_0', '33_0', 'Depot']
#  Vehicle 2 route: ['Depot', '19_1', '14_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
#  Vehicle 3 route: ['Depot', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
#  Vehicle 4 route: ['Depot', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '4_0', '1_0', '11_0', '15_0', '43_0', '21_0', '16_0', '5_0', 'Depot']
#  Vehicle 5 route: ['Depot', '22_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '54_0', 'Depot']
# Total distance traveled by all vehicles: 2617.40 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for CELEBRATION on 2017-08-16: 785.27 USD
# Map saved as CELEBRATION_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for CLEANING on 2017-08-16, Vehicles: 2
#  Vehicle 1 route: ['Depot', '11_0', '15_0', '43_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '42_0', '37_0', '39_0', '51_0', '32_0', '28_0', '29_0', '26_0', '24_0', '30_0', '34_0', '27_0', '36_0', '31_0', '19_0', '33_0', '54_0', '5_0', '16_0', '21_0', 'Depot']
#  Vehicle 2 route: ['Depot', '13_0', '12_0', '50_0', '23_0', '14_0', '22_0', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', 'Depot']
# Total distance traveled by all vehicles: 2054.55 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for CLEANING on 2017-08-16: 619.61 USD
# Map saved as CLEANING_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for DAIRY on 2017-08-16, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for DAIRY on 2017-08-16: 565.78 USD
# Map saved as DAIRY_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for DELI on 2017-08-16, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for DELI on 2017-08-16: 565.78 USD
# Map saved as DELI_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for EGGS on 2017-08-16, Vehicles: 2
#  Vehicle 1 route: ['Depot', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
#  Vehicle 2 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for EGGS on 2017-08-16: 573.39 USD
# Map saved as EGGS_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for FROZEN FOODS on 2017-08-16, Vehicles: 5
#  Vehicle 1 route: ['Depot', '13_0', 'Depot']
#  Vehicle 2 route: ['Depot', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '17_0', 'Depot']
#  Vehicle 3 route: ['Depot', '12_0', '50_0', '23_0', '14_0', '39_0', '42_0', '37_0', '22_0', 'Depot']
#  Vehicle 4 route: ['Depot', '21_0', '16_0', '5_0', '54_0', '33_0', '19_0', '31_0', '36_0', '27_0', '34_0', '30_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '43_0', '15_0', '11_0', 'Depot']
#  Vehicle 5 route: ['Depot', '46_0', 'Depot']
# Total distance traveled by all vehicles: 2426.23 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for FROZEN FOODS on 2017-08-16: 729.00 USD
# Map saved as FROZEN_FOODS_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for GROCERY I on 2017-08-16, Vehicles: 4
#  Vehicle 1 route: ['Depot', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '4_0', '10_0', '20_0', '6_0', 'Depot']
#  Vehicle 2 route: ['Depot', '17_0', '9_0', '45_0', '1_0', '11_0', '15_0', '43_0', '21_0', '16_0', '5_0', 'Depot']
#  Vehicle 3 route: ['Depot', '33_0', '25_0', '53_0', '52_0', '54_0', 'Depot']
#  Vehicle 4 route: ['Depot', '22_0', '14_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '35_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '30_0', '34_0', '27_0', '36_0', '31_0', '19_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
# Total distance traveled by all vehicles: 2371.15 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for GROCERY I on 2017-08-16: 712.79 USD
# Map saved as GROCERY_I_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for GROCERY II on 2017-08-16, Vehicles: 2
#  Vehicle 1 route: ['Depot', '21_0', '16_0', '5_0', '54_0', '33_0', '53_0', '52_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
#  Vehicle 2 route: ['Depot', '22_0', '14_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '35_0', '25_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '30_0', '34_0', '27_0', '36_0', '31_0', '19_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
# Total distance traveled by all vehicles: 2075.41 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for GROCERY II on 2017-08-16: 625.74 USD
# Map saved as GROCERY_II_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for HARDWARE on 2017-08-16, Vehicles: 5
#  Vehicle 1 route: ['Depot', '21_0', '16_0', '5_0', 'Depot']
#  Vehicle 2 route: ['Depot', '54_0', '33_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '31_0', '19_0', '23_0', '50_0', '13_0', 'Depot']
#  Vehicle 3 route: ['Depot', '6_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '47_0', '18_0', '2_0', '49_0', '3_0', '46_0', 'Depot']
#  Vehicle 4 route: ['Depot', '44_0', '48_0', '7_0', '9_0', '17_0', 'Depot']
#  Vehicle 5 route: ['Depot', '11_0', '15_0', '43_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '39_0', '42_0', '37_0', '14_0', '22_0', '12_0', 'Depot']
# Total distance traveled by all vehicles: 2342.04 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for HARDWARE on 2017-08-16: 704.22 USD
# Map saved as HARDWARE_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for HOME AND KITCHEN I on 2017-08-16, Vehicles: 3
#  Vehicle 1 route: ['Depot', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', 'Depot']
#  Vehicle 2 route: ['Depot', '22_0', '14_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '35_0', '25_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '30_0', '34_0', '27_0', '36_0', '31_0', '19_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
#  Vehicle 3 route: ['Depot', '11_0', '15_0', '43_0', '52_0', '53_0', '33_0', '54_0', '5_0', '16_0', '21_0', 'Depot']
# Total distance traveled by all vehicles: 2101.29 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for HOME AND KITCHEN I on 2017-08-16: 633.36 USD
# Map saved as HOME_AND_KITCHEN_I_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for HOME AND KITCHEN II on 2017-08-16, Vehicles: 5
#  Vehicle 1 route: ['Depot', '11_0', '15_0', '43_0', '52_0', '53_0', '25_0', '35_0', '32_0', '28_0', '51_0', '29_0', '34_0', '30_0', '36_0', 'Depot']
#  Vehicle 2 route: ['Depot', '17_0', '44_0', '3_0', '46_0', 'Depot']
#  Vehicle 3 route: ['Depot', '21_0', '16_0', '5_0', '54_0', '33_0', '31_0', '19_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
#  Vehicle 4 route: ['Depot', '20_0', '45_0', '9_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '6_0', 'Depot']
#  Vehicle 5 route: ['Depot', '27_0', '24_0', '26_0', '41_0', '40_0', '38_0', '39_0', '42_0', '37_0', '14_0', '22_0', 'Depot']
# Total distance traveled by all vehicles: 2654.06 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for HOME AND KITCHEN II on 2017-08-16: 796.06 USD
# Map saved as HOME_AND_KITCHEN_II_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for HOME APPLIANCES on 2017-08-16, Vehicles: 4
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '50_0', '23_0', '19_0', '33_0', 'Depot']
#  Vehicle 2 route: ['Depot', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '7_0', '47_0', '43_0', '15_0', '11_0', 'Depot']
#  Vehicle 3 route: ['Depot', '21_0', '16_0', '5_0', '54_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '42_0', '37_0', '39_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '34_0', '30_0', '27_0', '36_0', '31_0', '14_0', '22_0', 'Depot']
#  Vehicle 4 route: ['Depot', '17_0', '9_0', '20_0', '45_0', '8_0', '1_0', '4_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 2248.21 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for HOME APPLIANCES on 2017-08-16: 676.61 USD
# Map saved as HOME_APPLIANCES_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for HOME CARE on 2017-08-16, Vehicles: 3
#  Vehicle 1 route: ['Depot', '21_0', '16_0', '5_0', '54_0', '33_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '43_0', '15_0', '11_0', '1_0', '4_0', '45_0', '20_0', '9_0', '17_0', 'Depot']
#  Vehicle 2 route: ['Depot', '22_0', '6_0', '10_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', 'Depot']
#  Vehicle 3 route: ['Depot', '19_0', '31_0', '14_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
# Total distance traveled by all vehicles: 2356.18 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for HOME CARE on 2017-08-16: 708.39 USD
# Map saved as HOME_CARE_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for LADIESWEAR on 2017-08-16, Vehicles: 3
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', 'Depot']
#  Vehicle 2 route: ['Depot', '11_0', '15_0', '43_0', 'Depot']
#  Vehicle 3 route: ['Depot', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', 'Depot']
# Total distance traveled by all vehicles: 2024.48 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for LADIESWEAR on 2017-08-16: 610.75 USD
# Map saved as LADIESWEAR_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for LAWN AND GARDEN on 2017-08-16, Vehicles: 3
#  Vehicle 1 route: ['Depot', '12_0', '50_0', '23_0', '19_0', '14_0', '22_0', 'Depot']
#  Vehicle 2 route: ['Depot', '11_0', '15_0', '43_0', '21_0', '16_0', '5_0', '54_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '42_0', '37_0', '39_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '34_0', '30_0', '27_0', '36_0', '31_0', '33_0', '13_0', 'Depot']
#  Vehicle 3 route: ['Depot', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 2126.77 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for LAWN AND GARDEN on 2017-08-16: 640.86 USD
# Map saved as LAWN_AND_GARDEN_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for LINGERIE on 2017-08-16, Vehicles: 3
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '50_0', '23_0', '19_0', '31_0', '27_0', '25_0', '35_0', '41_0', '40_0', '38_0', '39_0', '42_0', '37_0', '14_0', '22_0', 'Depot']
#  Vehicle 2 route: ['Depot', '33_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '36_0', 'Depot']
#  Vehicle 3 route: ['Depot', '21_0', '16_0', '5_0', '54_0', '53_0', '52_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 2554.25 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for LINGERIE on 2017-08-16: 766.69 USD
# Map saved as LINGERIE_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for LIQUOR,WINE,BEER on 2017-08-16, Vehicles: 4
# No VRP solution found.
#
# VRP routing for MAGAZINES on 2017-08-16, Vehicles: 5
#  Vehicle 1 route: ['Depot', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', 'Depot']
#  Vehicle 2 route: ['Depot', '5_0', '16_0', '21_0', 'Depot']
#  Vehicle 3 route: ['Depot', '33_0', '25_0', '27_0', '36_0', '31_0', '19_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
#  Vehicle 4 route: ['Depot', '11_0', '15_0', '43_0', '54_0', '52_0', '53_0', '34_0', '30_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '35_0', '41_0', '40_0', '38_0', '39_0', '42_0', '37_0', '14_0', '22_0', 'Depot']
#  Vehicle 5 route: ['Depot', '17_0', '9_0', '20_0', '45_0', '4_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 2466.00 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for MAGAZINES on 2017-08-16: 740.71 USD
# Map saved as MAGAZINES_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for MEATS on 2017-08-16, Vehicles: 2
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', 'Depot']
#  Vehicle 2 route: ['Depot', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for MEATS on 2017-08-16: 573.39 USD
# Map saved as MEATS_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for PERSONAL CARE on 2017-08-16, Vehicles: 5
#  Vehicle 1 route: ['Depot', '22_0', '38_0', '40_0', '41_0', '14_0', '13_0', 'Depot']
#  Vehicle 2 route: ['Depot', '21_0', '16_0', '5_0', '54_0', '33_0', '36_0', '27_0', '34_0', '30_0', '24_0', '31_0', '19_0', 'Depot']
#  Vehicle 3 route: ['Depot', '12_0', '50_0', '23_0', '37_0', '42_0', '39_0', '26_0', '29_0', '51_0', '28_0', '32_0', '35_0', '25_0', '53_0', '52_0', '43_0', '15_0', '11_0', '1_0', '4_0', '10_0', '6_0', 'Depot']
#  Vehicle 4 route: ['Depot', '17_0', '48_0', '49_0', '3_0', '46_0', 'Depot']
#  Vehicle 5 route: ['Depot', '44_0', '2_0', '18_0', '47_0', '7_0', '8_0', '45_0', '20_0', '9_0', 'Depot']
# Total distance traveled by all vehicles: 2895.62 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for PERSONAL CARE on 2017-08-16: 867.17 USD
# Map saved as PERSONAL_CARE_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for PET SUPPLIES on 2017-08-16, Vehicles: 10
# No VRP solution found.
#
# VRP routing for PLAYERS AND ELECTRONICS on 2017-08-16, Vehicles: 10
#  Vehicle 1 route: ['Depot', '1_0', '8_0', '7_1', '17_0', 'Depot']
#  Vehicle 2 route: ['Depot', '30_0', '24_0', '26_0', '29_0', '51_0', '40_0', '41_0', 'Depot']
#  Vehicle 3 route: ['Depot', '27_0', '34_0', '28_0', '32_0', '35_0', '25_0', 'Depot']
#  Vehicle 4 route: ['Depot', '11_0', '15_0', '43_0', '52_0', '53_0', '25_1', 'Depot']
#  Vehicle 5 route: ['Depot', '19_0', '31_0', '39_0', '42_0', '37_0', '14_0', 'Depot']
#  Vehicle 6 route: ['Depot', '33_0', '36_0', '31_1', 'Depot']
#  Vehicle 7 route: ['Depot', '22_0', '38_0', '40_1', '54_0', '5_0', '16_0', '21_0', 'Depot']
#  Vehicle 8 route: ['Depot', '48_0', '18_0', '47_0', '7_0', '9_0', 'Depot']
#  Vehicle 9 route: ['Depot', '50_0', '23_0', '12_0', '13_0', '20_0', '45_0', '4_0', '10_0', '6_0', 'Depot']
#  Vehicle 10 route: ['Depot', '46_0', '3_0', '49_0', '2_0', '44_0', 'Depot']
# Total distance traveled by all vehicles: 4948.38 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for PLAYERS AND ELECTRONICS on 2017-08-16: 1471.37 USD
# Map saved as PLAYERS_AND_ELECTRONICS_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for POULTRY on 2017-08-16, Vehicles: 4
#  Vehicle 1 route: ['Depot', '22_0', '14_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '35_0', '25_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '30_0', '34_0', '27_0', '36_0', '31_0', '33_0', 'Depot']
#  Vehicle 2 route: ['Depot', '17_0', '9_0', '20_0', '45_0', '1_0', '11_0', '15_0', '43_0', '52_0', '53_0', '54_0', '5_0', '16_0', '21_0', 'Depot']
#  Vehicle 3 route: ['Depot', '19_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
#  Vehicle 4 route: ['Depot', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '4_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 2333.36 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for POULTRY on 2017-08-16: 701.67 USD
# Map saved as POULTRY_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for PREPARED FOODS on 2017-08-16, Vehicles: 3
#  Vehicle 1 route: ['Depot', '21_0', '16_0', '5_0', '54_0', '33_0', '27_0', '36_0', '31_0', '19_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
#  Vehicle 2 route: ['Depot', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', 'Depot']
#  Vehicle 3 route: ['Depot', '22_0', '14_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '26_0', '24_0', '30_0', '34_0', '29_0', '51_0', '28_0', '32_0', '35_0', '25_0', '53_0', '52_0', '43_0', '15_0', '11_0', 'Depot']
# Total distance traveled by all vehicles: 2127.68 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for PREPARED FOODS on 2017-08-16: 641.13 USD
# Map saved as PREPARED_FOODS_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for PRODUCE on 2017-08-16, Vehicles: 3
#  Vehicle 1 route: ['Depot', '11_0', '15_0', '43_0', 'Depot']
#  Vehicle 2 route: ['Depot', '21_0', '16_0', '5_0', '54_0', '33_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '42_0', '37_0', '39_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '34_0', '30_0', '27_0', '36_0', '31_0', '19_0', '14_0', '22_0', '50_0', '23_0', '12_0', '13_0', 'Depot']
#  Vehicle 3 route: ['Depot', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', 'Depot']
# Total distance traveled by all vehicles: 2024.48 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for PRODUCE on 2017-08-16: 610.75 USD
# Map saved as PRODUCE_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for SCHOOL AND OFFICE SUPPLIES on 2017-08-16, Vehicles: 7
#  Vehicle 1 route: ['Depot', '13_0', 'Depot']
#  Vehicle 2 route: ['Depot', '11_0', '15_0', '43_0', '52_0', '53_0', '25_0', '35_0', '38_0', '39_0', '42_0', '37_0', '22_1', 'Depot']
#  Vehicle 3 route: ['Depot', '22_0', '14_0', '31_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '34_0', '30_0', '27_0', '36_0', '33_0', '54_0', 'Depot']
#  Vehicle 4 route: ['Depot', '17_0', '48_0', '49_0', '2_0', '18_0', '47_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
#  Vehicle 5 route: ['Depot', '7_0', '3_0', '44_0', 'Depot']
#  Vehicle 6 route: ['Depot', '41_0', '40_0', '19_0', 'Depot']
#  Vehicle 7 route: ['Depot', '12_0', '50_0', '23_0', '5_0', '16_0', '21_0', '46_0', 'Depot']
# Total distance traveled by all vehicles: 3402.63 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for SCHOOL AND OFFICE SUPPLIES on 2017-08-16: 1016.40 USD
# Map saved as SCHOOL_AND_OFFICE_SUPPLIES_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for SEAFOOD on 2017-08-16, Vehicles: 2
#  Vehicle 1 route: ['Depot', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', 'Depot']
#  Vehicle 2 route: ['Depot', '11_0', '15_0', '43_0', '21_0', '16_0', '5_0', '54_0', '33_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '42_0', '37_0', '39_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '34_0', '30_0', '27_0', '36_0', '31_0', '19_0', '14_0', '22_0', '50_0', '23_0', '12_0', '13_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-16: 0.2943396226415094 USD/liter
# Total delivery cost for SEAFOOD on 2017-08-16: 573.39 USD
# Map saved as SEAFOOD_Distribution_Transportation_Plan_2017-08-16.html
#
# VRP routing for BREAD/BAKERY on 2017-08-18, Vehicles: 2
#  Vehicle 1 route: ['Depot', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', 'Depot']
#  Vehicle 2 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-18: 0.30559748427672956 USD/liter
# Total delivery cost for BREAD/BAKERY on 2017-08-18: 594.76 USD
# Map saved as BREAD_BAKERY_Distribution_Transportation_Plan_2017-08-18.html
#
# VRP routing for DAIRY on 2017-08-18, Vehicles: 2
#  Vehicle 1 route: ['Depot', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
#  Vehicle 2 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-18: 0.30559748427672956 USD/liter
# Total delivery cost for DAIRY on 2017-08-18: 594.76 USD
# Map saved as DAIRY_Distribution_Transportation_Plan_2017-08-18.html
#
# VRP routing for DELI on 2017-08-18, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-18: 0.30559748427672956 USD/liter
# Total delivery cost for DELI on 2017-08-18: 586.85 USD
# Map saved as DELI_Distribution_Transportation_Plan_2017-08-18.html
#
# VRP routing for EGGS on 2017-08-18, Vehicles: 2
#  Vehicle 1 route: ['Depot', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
#  Vehicle 2 route: ['Depot', '11_0', '15_0', '43_0', '21_0', '16_0', '5_0', '54_0', '33_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '42_0', '37_0', '39_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '34_0', '30_0', '27_0', '36_0', '31_0', '19_0', '14_0', '22_0', '50_0', '23_0', '12_0', '13_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-18: 0.30559748427672956 USD/liter
# Total delivery cost for EGGS on 2017-08-18: 594.76 USD
# Map saved as EGGS_Distribution_Transportation_Plan_2017-08-18.html
#
# VRP routing for MEATS on 2017-08-18, Vehicles: 2
#  Vehicle 1 route: ['Depot', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', 'Depot']
#  Vehicle 2 route: ['Depot', '11_0', '15_0', '43_0', '21_0', '16_0', '5_0', '54_0', '33_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '42_0', '37_0', '39_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '34_0', '30_0', '27_0', '36_0', '31_0', '19_0', '14_0', '22_0', '50_0', '23_0', '12_0', '13_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-18: 0.30559748427672956 USD/liter
# Total delivery cost for MEATS on 2017-08-18: 594.76 USD
# Map saved as MEATS_Distribution_Transportation_Plan_2017-08-18.html
#
# VRP routing for POULTRY on 2017-08-18, Vehicles: 5
#  Vehicle 1 route: ['Depot', '19_0', '14_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
#  Vehicle 2 route: ['Depot', '6_0', '10_0', '45_0', '20_0', '9_0', '17_0', 'Depot']
#  Vehicle 3 route: ['Depot', '43_0', '52_0', '53_0', '54_0', 'Depot']
#  Vehicle 4 route: ['Depot', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '4_0', '1_0', '15_0', '11_0', 'Depot']
#  Vehicle 5 route: ['Depot', '21_0', '16_0', '5_0', '33_0', '31_0', '36_0', '27_0', '34_0', '30_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '25_0', '35_0', '41_0', '40_0', '38_0', '39_0', '42_0', '37_0', '22_0', 'Depot']
# Total distance traveled by all vehicles: 2511.27 km
# Oil price on 2017-08-18: 0.30559748427672956 USD/liter
# Total delivery cost for POULTRY on 2017-08-18: 782.31 USD
# Map saved as POULTRY_Distribution_Transportation_Plan_2017-08-18.html
#
# VRP routing for PREPARED FOODS on 2017-08-18, Vehicles: 3
#  Vehicle 1 route: ['Depot', '33_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '31_0', '19_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
#  Vehicle 2 route: ['Depot', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', 'Depot']
#  Vehicle 3 route: ['Depot', '22_0', '14_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', 'Depot']
# Total distance traveled by all vehicles: 2173.02 km
# Oil price on 2017-08-18: 0.30559748427672956 USD/liter
# Total delivery cost for PREPARED FOODS on 2017-08-18: 678.94 USD
# Map saved as PREPARED_FOODS_Distribution_Transportation_Plan_2017-08-18.html
#
# VRP routing for PRODUCE on 2017-08-18, Vehicles: 3
#  Vehicle 1 route: ['Depot', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '10_0', '6_0', 'Depot']
#  Vehicle 2 route: ['Depot', '13_0', '12_0', '50_0', '23_0', '19_0', '31_0', '36_0', '27_0', '34_0', '30_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '25_0', '35_0', '41_0', '40_0', '38_0', '39_0', '42_0', '37_0', '14_0', '22_0', 'Depot']
#  Vehicle 3 route: ['Depot', '17_0', '9_0', '20_0', '45_0', '4_0', '1_0', '11_0', '15_0', '43_0', '52_0', '53_0', '33_0', '54_0', '5_0', '16_0', '21_0', 'Depot']
# Total distance traveled by all vehicles: 2109.33 km
# Oil price on 2017-08-18: 0.30559748427672956 USD/liter
# Total delivery cost for PRODUCE on 2017-08-18: 659.48 USD
# Map saved as PRODUCE_Distribution_Transportation_Plan_2017-08-18.html
#
# VRP routing for SEAFOOD on 2017-08-18, Vehicles: 2
#  Vehicle 1 route: ['Depot', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', 'Depot']
#  Vehicle 2 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-18: 0.30559748427672956 USD/liter
# Total delivery cost for SEAFOOD on 2017-08-18: 594.76 USD
# Map saved as SEAFOOD_Distribution_Transportation_Plan_2017-08-18.html
#
# VRP routing for BREAD/BAKERY on 2017-08-20, Vehicles: 2
#  Vehicle 1 route: ['Depot', '11_0', '15_0', '43_0', '21_0', '16_0', '5_0', '54_0', '33_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '42_0', '37_0', '39_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '34_0', '30_0', '27_0', '36_0', '31_0', '19_0', '14_0', '22_0', '50_0', '23_0', '12_0', '13_0', 'Depot']
#  Vehicle 2 route: ['Depot', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-20: 0.30559748427672956 USD/liter
# Total delivery cost for BREAD/BAKERY on 2017-08-20: 594.76 USD
# Map saved as BREAD_BAKERY_Distribution_Transportation_Plan_2017-08-20.html
#
# VRP routing for DAIRY on 2017-08-20, Vehicles: 2
#  Vehicle 1 route: ['Depot', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
#  Vehicle 2 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-20: 0.30559748427672956 USD/liter
# Total delivery cost for DAIRY on 2017-08-20: 594.76 USD
# Map saved as DAIRY_Distribution_Transportation_Plan_2017-08-20.html
#
# VRP routing for DELI on 2017-08-20, Vehicles: 2
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', 'Depot']
#  Vehicle 2 route: ['Depot', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-20: 0.30559748427672956 USD/liter
# Total delivery cost for DELI on 2017-08-20: 594.76 USD
# Map saved as DELI_Distribution_Transportation_Plan_2017-08-20.html
#
# VRP routing for EGGS on 2017-08-20, Vehicles: 2
#  Vehicle 1 route: ['Depot', '11_0', '15_0', '43_0', '21_0', '16_0', '5_0', '54_0', '33_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '42_0', '37_0', '39_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '34_0', '30_0', '27_0', '36_0', '31_0', '19_0', '14_0', '22_0', '50_0', '23_0', '12_0', '13_0', 'Depot']
#  Vehicle 2 route: ['Depot', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-20: 0.30559748427672956 USD/liter
# Total delivery cost for EGGS on 2017-08-20: 594.76 USD
# Map saved as EGGS_Distribution_Transportation_Plan_2017-08-20.html
#
# VRP routing for MEATS on 2017-08-20, Vehicles: 2
#  Vehicle 1 route: ['Depot', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
#  Vehicle 2 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-20: 0.30559748427672956 USD/liter
# Total delivery cost for MEATS on 2017-08-20: 594.76 USD
# Map saved as MEATS_Distribution_Transportation_Plan_2017-08-20.html
#
# VRP routing for POULTRY on 2017-08-20, Vehicles: 5
#  Vehicle 1 route: ['Depot', '12_0', '11_0', '15_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', 'Depot']
#  Vehicle 2 route: ['Depot', '50_0', '23_0', '14_0', '19_0', '13_0', 'Depot']
#  Vehicle 3 route: ['Depot', '31_0', '24_0', '26_0', '30_0', '34_0', '29_0', '51_0', '28_0', '32_0', '35_0', '25_0', '53_0', '52_0', '54_0', 'Depot']
#  Vehicle 4 route: ['Depot', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
#  Vehicle 5 route: ['Depot', '22_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '27_0', '36_0', '33_0', '5_0', '16_0', '21_0', '43_0', 'Depot']
# Total distance traveled by all vehicles: 2809.21 km
# Oil price on 2017-08-20: 0.30559748427672956 USD/liter
# Total delivery cost for POULTRY on 2017-08-20: 873.36 USD
# Map saved as POULTRY_Distribution_Transportation_Plan_2017-08-20.html
#
# VRP routing for PREPARED FOODS on 2017-08-20, Vehicles: 3
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '50_0', '23_0', '19_0', '31_0', '24_0', '26_0', '30_0', '34_0', '29_0', '51_0', '28_0', '32_0', '35_0', '25_0', '53_0', '52_0', '43_0', 'Depot']
#  Vehicle 2 route: ['Depot', '22_0', '14_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '27_0', '36_0', '33_0', '54_0', '5_0', '16_0', '21_0', 'Depot']
#  Vehicle 3 route: ['Depot', '6_0', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '15_0', '11_0', 'Depot']
# Total distance traveled by all vehicles: 2300.47 km
# Oil price on 2017-08-20: 0.30559748427672956 USD/liter
# Total delivery cost for PREPARED FOODS on 2017-08-20: 717.89 USD
# Map saved as PREPARED_FOODS_Distribution_Transportation_Plan_2017-08-20.html
#
# VRP routing for PRODUCE on 2017-08-20, Vehicles: 3
#  Vehicle 1 route: ['Depot', '19_0', '31_0', '36_0', '27_0', '30_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '34_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '39_0', '42_0', '37_0', '14_0', '22_0', 'Depot']
#  Vehicle 2 route: ['Depot', '17_0', '9_0', '20_0', '45_0', '1_0', '4_0', '10_0', '6_0', 'Depot']
#  Vehicle 3 route: ['Depot', '13_0', '12_0', '50_0', '23_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', 'Depot']
# Total distance traveled by all vehicles: 2158.05 km
# Oil price on 2017-08-20: 0.30559748427672956 USD/liter
# Total delivery cost for PRODUCE on 2017-08-20: 674.36 USD
# Map saved as PRODUCE_Distribution_Transportation_Plan_2017-08-20.html
#
# VRP routing for SEAFOOD on 2017-08-20, Vehicles: 2
#  Vehicle 1 route: ['Depot', '21_0', '16_0', '5_0', '54_0', '33_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '43_0', '15_0', '11_0', 'Depot']
#  Vehicle 2 route: ['Depot', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', '22_0', '14_0', '19_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
# Total distance traveled by all vehicles: 2068.50 km
# Oil price on 2017-08-20: 0.30559748427672956 USD/liter
# Total delivery cost for SEAFOOD on 2017-08-20: 647.00 USD
# Map saved as SEAFOOD_Distribution_Transportation_Plan_2017-08-20.html
#
# VRP routing for AUTOMOTIVE on 2017-08-21, Vehicles: 4
#  Vehicle 1 route: ['Depot', '46_0', '44_0', '9_0', '45_0', '20_0', '6_0', 'Depot']
#  Vehicle 2 route: ['Depot', '21_0', '16_0', '5_0', '54_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '39_0', '42_0', '37_0', '14_0', '22_0', 'Depot']
#  Vehicle 3 route: ['Depot', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '3_0', '48_0', '17_0', '13_0', 'Depot']
#  Vehicle 4 route: ['Depot', '11_0', '15_0', '43_0', '33_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '31_0', '19_0', '23_0', '50_0', '12_0', 'Depot']
# Total distance traveled by all vehicles: 2357.13 km
# Oil price on 2017-08-21: 0.2980503144654088 USD/liter
# Total delivery cost for AUTOMOTIVE on 2017-08-21: 717.41 USD
# Map saved as AUTOMOTIVE_Distribution_Transportation_Plan_2017-08-21.html
#
# VRP routing for BABY CARE on 2017-08-21, Vehicles: 7
# No VRP solution found.
#
# VRP routing for BEAUTY on 2017-08-21, Vehicles: 3
#  Vehicle 1 route: ['Depot', '21_0', '16_0', '5_0', '54_0', '33_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '31_0', '19_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
#  Vehicle 2 route: ['Depot', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
#  Vehicle 3 route: ['Depot', '22_0', '14_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '43_0', '15_0', '11_0', 'Depot']
# Total distance traveled by all vehicles: 2143.12 km
# Oil price on 2017-08-21: 0.2980503144654088 USD/liter
# Total delivery cost for BEAUTY on 2017-08-21: 653.63 USD
# Map saved as BEAUTY_Distribution_Transportation_Plan_2017-08-21.html
#
# VRP routing for BEVERAGES on 2017-08-21, Vehicles: 5
# No VRP solution found.
#
# VRP routing for BOOKS on 2017-08-21, Vehicles: 6
#  Vehicle 1 route: ['Depot', '22_0', '14_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '35_0', '25_0', '32_0', '51_0', '29_0', '26_0', '24_0', '27_0', '33_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
#  Vehicle 2 route: ['Depot', '11_0', '15_0', '43_0', '52_0', '53_0', '54_0', '5_0', '16_0', '21_0', 'Depot']
#  Vehicle 3 route: ['Depot', '31_0', '30_0', '28_0', '34_0', '36_0', 'Depot']
#  Vehicle 4 route: ['Depot', '17_0', '46_0', 'Depot']
#  Vehicle 5 route: ['Depot', '12_0', '50_0', '23_0', '19_0', 'Depot']
#  Vehicle 6 route: ['Depot', '13_0', 'Depot']
# Total distance traveled by all vehicles: 3004.45 km
# Oil price on 2017-08-21: 0.2980503144654088 USD/liter
# Total delivery cost for BOOKS on 2017-08-21: 910.35 USD
# Map saved as BOOKS_Distribution_Transportation_Plan_2017-08-21.html
#
# VRP routing for CELEBRATION on 2017-08-21, Vehicles: 5
#  Vehicle 1 route: ['Depot', '33_0', '27_0', '36_0', '31_0', '19_0', 'Depot']
#  Vehicle 2 route: ['Depot', '6_0', '10_0', '45_0', '20_0', '9_0', '17_0', 'Depot']
#  Vehicle 3 route: ['Depot', '19_1', '14_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
#  Vehicle 4 route: ['Depot', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '4_0', '1_0', '11_0', '15_0', '43_0', '21_0', '16_0', '5_0', 'Depot']
#  Vehicle 5 route: ['Depot', '22_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '26_0', '24_0', '30_0', '34_0', '29_0', '51_0', '28_0', '32_0', '35_0', '25_0', '53_0', '52_0', '54_0', 'Depot']
# Total distance traveled by all vehicles: 2601.96 km
# Oil price on 2017-08-21: 0.2980503144654088 USD/liter
# Total delivery cost for CELEBRATION on 2017-08-21: 790.38 USD
# Map saved as CELEBRATION_Distribution_Transportation_Plan_2017-08-21.html
#
# VRP routing for CLEANING on 2017-08-21, Vehicles: 2
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '50_0', '23_0', '14_0', '22_0', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', 'Depot']
#  Vehicle 2 route: ['Depot', '11_0', '15_0', '43_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '42_0', '37_0', '39_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '34_0', '30_0', '27_0', '36_0', '31_0', '19_0', '33_0', '54_0', '5_0', '16_0', '21_0', 'Depot']
# Total distance traveled by all vehicles: 2054.29 km
# Oil price on 2017-08-21: 0.2980503144654088 USD/liter
# Total delivery cost for CLEANING on 2017-08-21: 627.15 USD
# Map saved as CLEANING_Distribution_Transportation_Plan_2017-08-21.html
#
# VRP routing for FROZEN FOODS on 2017-08-21, Vehicles: 4
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '50_0', '23_0', '14_0', '39_0', '31_0', '36_0', '27_0', '34_0', '30_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '35_0', '25_0', '53_0', '52_0', '43_0', '15_0', '11_0', 'Depot']
#  Vehicle 2 route: ['Depot', '22_0', '37_0', '42_0', '38_0', '40_0', '41_0', '19_0', '33_0', '54_0', '5_0', '16_0', '21_0', 'Depot']
#  Vehicle 3 route: ['Depot', '46_0', 'Depot']
#  Vehicle 4 route: ['Depot', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '17_0', 'Depot']
# Total distance traveled by all vehicles: 2449.59 km
# Oil price on 2017-08-21: 0.2980503144654088 USD/liter
# Total delivery cost for FROZEN FOODS on 2017-08-21: 744.97 USD
# Map saved as FROZEN_FOODS_Distribution_Transportation_Plan_2017-08-21.html
#
# VRP routing for GROCERY I on 2017-08-21, Vehicles: 4
#  Vehicle 1 route: ['Depot', '21_0', '16_0', '5_0', 'Depot']
#  Vehicle 2 route: ['Depot', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', 'Depot']
#  Vehicle 3 route: ['Depot', '11_0', '15_0', '43_0', '52_0', '53_0', '33_0', '54_0', 'Depot']
#  Vehicle 4 route: ['Depot', '13_0', '12_0', '50_0', '23_0', '19_0', '31_0', '36_0', '27_0', '34_0', '30_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '25_0', '35_0', '41_0', '40_0', '38_0', '39_0', '42_0', '37_0', '14_0', '22_0', 'Depot']
# Total distance traveled by all vehicles: 2245.27 km
# Oil price on 2017-08-21: 0.2980503144654088 USD/liter
# Total delivery cost for GROCERY I on 2017-08-21: 684.07 USD
# Map saved as GROCERY_I_Distribution_Transportation_Plan_2017-08-21.html
#
# VRP routing for GROCERY II on 2017-08-21, Vehicles: 2
#  Vehicle 1 route: ['Depot', '22_0', '14_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '35_0', '25_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '30_0', '34_0', '27_0', '36_0', '31_0', '19_0', '23_0', '50_0', '12_0', '13_0', 'Depot']
#  Vehicle 2 route: ['Depot', '21_0', '16_0', '5_0', '54_0', '33_0', '53_0', '52_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 2075.41 km
# Oil price on 2017-08-21: 0.2980503144654088 USD/liter
# Total delivery cost for GROCERY II on 2017-08-21: 633.45 USD
# Map saved as GROCERY_II_Distribution_Transportation_Plan_2017-08-21.html
#
# VRP routing for HARDWARE on 2017-08-21, Vehicles: 5
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '22_0', '14_0', '37_0', '42_0', '39_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '43_0', '15_0', '11_0', 'Depot']
#  Vehicle 2 route: ['Depot', '46_0', '3_0', '49_0', '9_0', '45_0', '20_0', 'Depot']
#  Vehicle 3 route: ['Depot', '21_0', '16_0', '5_0', 'Depot']
# ...
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for BEVERAGES on 2017-08-31: 571.19 USD
# Map saved as BEVERAGES_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for BOOKS on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for BOOKS on 2017-08-31: 571.19 USD
# Map saved as BOOKS_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for CELEBRATION on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for CELEBRATION on 2017-08-31: 571.19 USD
# Map saved as CELEBRATION_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for CLEANING on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for CLEANING on 2017-08-31: 571.19 USD
# Map saved as CLEANING_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for FROZEN FOODS on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for FROZEN FOODS on 2017-08-31: 571.19 USD
# Map saved as FROZEN_FOODS_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for GROCERY I on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for GROCERY I on 2017-08-31: 571.19 USD
# Map saved as GROCERY_I_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for GROCERY II on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for GROCERY II on 2017-08-31: 571.19 USD
# Map saved as GROCERY_II_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for HARDWARE on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for HARDWARE on 2017-08-31: 571.19 USD
# Map saved as HARDWARE_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for HOME AND KITCHEN I on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for HOME AND KITCHEN I on 2017-08-31: 571.19 USD
# Map saved as HOME_AND_KITCHEN_I_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for HOME AND KITCHEN II on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for HOME AND KITCHEN II on 2017-08-31: 571.19 USD
# Map saved as HOME_AND_KITCHEN_II_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for HOME APPLIANCES on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for HOME APPLIANCES on 2017-08-31: 571.19 USD
# Map saved as HOME_APPLIANCES_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for HOME CARE on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for HOME CARE on 2017-08-31: 571.19 USD
# Map saved as HOME_CARE_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for LADIESWEAR on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for LADIESWEAR on 2017-08-31: 571.19 USD
# Map saved as LADIESWEAR_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for LAWN AND GARDEN on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for LAWN AND GARDEN on 2017-08-31: 571.19 USD
# Map saved as LAWN_AND_GARDEN_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for LINGERIE on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for LINGERIE on 2017-08-31: 571.19 USD
# Map saved as LINGERIE_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for LIQUOR,WINE,BEER on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for LIQUOR,WINE,BEER on 2017-08-31: 571.19 USD
# Map saved as LIQUOR_WINE_BEER_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for MAGAZINES on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for MAGAZINES on 2017-08-31: 571.19 USD
# Map saved as MAGAZINES_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for PERSONAL CARE on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for PERSONAL CARE on 2017-08-31: 571.19 USD
# Map saved as PERSONAL_CARE_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for PET SUPPLIES on 2017-08-31, Vehicles: 2
#  Vehicle 1 route: ['Depot', '50_0', '23_0', '12_0', '13_0', '17_0', '46_0', '44_0', '3_0', '48_0', '49_0', '2_0', '18_0', '47_0', '7_0', '8_0', '1_0', '4_0', '10_0', '45_0', '20_0', '9_0', '6_0', 'Depot']
#  Vehicle 2 route: ['Depot', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', 'Depot']
# Total distance traveled by all vehicles: 2054.68 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for PET SUPPLIES on 2017-08-31: 625.59 USD
# Map saved as PET_SUPPLIES_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for PLAYERS AND ELECTRONICS on 2017-08-31, Vehicles: 2
#  Vehicle 1 route: ['Depot', '6_0', '9_0', '20_0', '45_0', '10_0', '4_0', '1_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', 'Depot']
#  Vehicle 2 route: ['Depot', '11_0', '15_0', '43_0', '21_0', '16_0', '5_0', '54_0', '33_0', '52_0', '53_0', '25_0', '35_0', '41_0', '40_0', '38_0', '42_0', '37_0', '39_0', '24_0', '26_0', '29_0', '51_0', '28_0', '32_0', '34_0', '30_0', '27_0', '36_0', '31_0', '19_0', '14_0', '22_0', '50_0', '23_0', '12_0', '13_0', 'Depot']
# Total distance traveled by all vehicles: 1897.55 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for PLAYERS AND ELECTRONICS on 2017-08-31: 578.88 USD
# Map saved as PLAYERS_AND_ELECTRONICS_Distribution_Transportation_Plan_2017-08-31.html
#
# VRP routing for SCHOOL AND OFFICE SUPPLIES on 2017-08-31, Vehicles: 1
#  Vehicle 1 route: ['Depot', '13_0', '12_0', '23_0', '50_0', '22_0', '14_0', '19_0', '31_0', '36_0', '27_0', '30_0', '34_0', '32_0', '28_0', '51_0', '29_0', '26_0', '24_0', '39_0', '37_0', '42_0', '38_0', '40_0', '41_0', '35_0', '25_0', '53_0', '52_0', '33_0', '54_0', '5_0', '16_0', '21_0', '43_0', '15_0', '11_0', '1_0', '4_0', '8_0', '7_0', '47_0', '18_0', '2_0', '49_0', '48_0', '3_0', '44_0', '46_0', '17_0', '9_0', '20_0', '45_0', '10_0', '6_0', 'Depot']
# Total distance traveled by all vehicles: 1871.67 km
# Oil price on 2017-08-31: 0.2972327044025157 USD/liter
# Total delivery cost for SCHOOL AND OFFICE SUPPLIES on 2017-08-31: 571.19 USD
# Map saved as SCHOOL_AND_OFFICE_SUPPLIES_Distribution_Transportation_Plan_2017-08-31.html
